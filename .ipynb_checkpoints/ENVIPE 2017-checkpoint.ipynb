# %%
import pandas as pd
file = '../Datasets/envipe_2017_csv/0_indice_tablas_envipe2017.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#   Encuesta Nacional de Victimización y Percepción sobre Seguridad Pública 2017  \
# 0                                                NaN
# 1                                  Nombre de archivo
# 2                                             thogar
# 3                                           tmod_vic
# 4                                          tper_vic1
# 5                                          tper_vic2
# 6                                              tsdem
# 7                                          tvivienda
#
#                                 Unnamed: 1
# 0                                      NaN
# 1                         Título de Tablas
# 2               Información de los hogares
# 3                  Módulo de victimización
# 4  Sección 4, 5 del cuestionario principal
# 5  Sección 6, 7 del cuestionario principal
# 6     Sección 3 del cuestionario principal
# 7           Sección 1 y 2 del cuestionario

# %%
file = '../Datasets/envipe_2017_csv/thogar_envipe2017/diccionario_de_datos/diccionario_de_datos_thogar.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                     NOMBRE_CAMPO    NEMÓNICO          TIPO  \
# 0         Identificador de vivienda seleccionada      ID_VIV  Alfanumérico
# 1           Identificador del hogar seleccionado      ID_HOG  Alfanumérico
# 2                      Control de vivienda (UPM)         UPM      Numérico
# 3                          Vivienda seleccionada     VIV_SEL      Numérico
# 4                              Control del hogar       HOGAR      Numérico
# 5                Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 6                Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 7                Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 8                Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 9          Número de renglón del (la) informante       N_INF      Numérico
# 10  Número de renglón de la persona seleccionada       R_SEL      Numérico
# ...

# %%
file = '../Datasets/envipe_2017_csv/tmod_vic_envipe2017/diccionario_de_datos/diccionario_de_datos_tmod_vic.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                           NOMBRE_CAMPO    NEMÓNICO  \
# 0               Identificador de vivienda seleccionada      ID_VIV
# 1                 Identificador del hogar seleccionado      ID_HOG
# 2                          Identificador de la persona      ID_PER
# 3                             Identificador del delito      ID_DEL
# 4                            Control de vivienda (UPM)         UPM
# 5                                Vivienda seleccionada     VIV_SEL
# 6                                    Control del hogar       HOGAR
# 7                            Número de delito por tipo     ND_TIPO
# 8                            Total de delitos por tipo     TD_TIPO
# 9                                 Códigos para delitos       BPCOD
# 10                                Códigos para delitos       BPCOD
# 11                                Códigos para delitos       BPCOD
# 12                                Códigos para delitos       BPCOD
# ...

# %%
file = '../Datasets/envipe_2017_csv/tper_vic1_envipe2017/diccionario_de_datos/diccionario_de_datos_tper_vic1.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                           NOMBRE_CAMPO    NEMÓNICO  \
# 0               Identificador de vivienda seleccionada      ID_VIV
# 1                 Identificador del hogar seleccionado      ID_HOG
# 2            Identificador del informante seleccionado      ID_PER
# 3                            Control de vivienda (UPM)         UPM
# 4                                Vivienda seleccionada     VIV_SEL
# 5                                    Control del hogar       HOGAR
# 6                      Resultado de la visita al hogar     RESUL_H
# 7                      Resultado de la visita al hogar     RESUL_H
# 8         Número de renglón de la persona seleccionada       R_SEL
# 9                                                 Sexo        SEXO
# 10                                                Sexo        SEXO
# 11                                                Edad        EDAD
# 12                                                Edad        EDAD
# ...

# %%
file = '../Datasets/envipe_2017_csv/tper_vic2_envipe2017/diccionario_de_datos/diccionario_de_datos_tper_vic2.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                           NOMBRE_CAMPO    NEMÓNICO  \
# 0                         Identificador de la vivienda      ID_VIV
# 1                              Identificador del hogar      ID_HOG
# 2            Identificador del informante seleccionado      ID_PER
# 3                            Control de vivienda (UPM)         UPM
# 4                                Vivienda seleccionada     VIV_SEL
# 5                                    Control del hogar       HOGAR
# 6                      Resultado de la visita al hogar     RESUL_H
# 7                      Resultado de la visita al hogar     RESUL_H
# 8         Número de renglón de la persona seleccionada       R_SEL
# 9                                                 Sexo        SEXO
# 10                                                Sexo        SEXO
# 11                                                Edad        EDAD
# 12                                                Edad        EDAD
# ...

# %%
file = '../Datasets/envipe_2017_csv/tsdem_envipe2017/diccionario_de_datos/diccionario_de_datos_tsdem.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                               NOMBRE_CAMPO    NEMÓNICO          TIPO  \
# 0   Identificador de vivienda seleccionada      ID_VIV  Alfanumérico
# 1     Identificador del hogar seleccionado      ID_HOG  Alfanumérico
# 2                    Identificador persona      ID_PER  Alfanumérico
# 3                Control de vivienda (UPM)         UPM      Numérico
# 4                    Vivienda seleccionada     VIV_SEL      Numérico
# 5                        Control del hogar       HOGAR      Numérico
# 6          Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 7          Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 8          Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 9         Número de renglón del informante       N_REN      Numérico
# 10        Parentesco con el Jefe del Hogar       PAREN      Numérico
# 11        Parentesco con el Jefe del Hogar       PAREN      Numérico
# 12        Parentesco con el Jefe del Hogar       PAREN      Numérico
# ...

# %%
file = '../Datasets/envipe_2017_csv/tvivienda_envipe2017/diccionario_de_datos/diccionario_de_datos_tvivienda.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                         NOMBRE_CAMPO    NEMÓNICO  \
# 0             Identificador de vivienda seleccionada      ID_VIV
# 1                          Control de vivienda (UPM)         UPM
# 2                              Vivienda seleccionada     VIV_SEL
# 3                                 Área metropolitana       AREAM
# 4                                 Área metropolitana       AREAM
# 5                                 Área metropolitana       AREAM
# 6                                 Área metropolitana       AREAM
# 7                                 Área metropolitana       AREAM
# 8                                 Área metropolitana       AREAM
# 9                                 Área metropolitana       AREAM
# 10                                Área metropolitana       AREAM
# 11                                Área metropolitana       AREAM
# 12                                Área metropolitana       AREAM
# ...
