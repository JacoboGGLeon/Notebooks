# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import requests

GOOGLE_MAPS_API_URL = 'http://maps.googleapis.com/maps/api/geocode/json'

# %%
data={}

data=[{'date': ['19 DE AGOSTO DE 2015'],
       'address': ['calle Yuriria, manzana 26, lote 12, colonia Valle de Anáhuac'],
       'link': ['https://afondoedomex.com/zona-oriente/secuestradores-tenian-a-tres-victimas-en-una-casa-de-seguridad-de-ecatepec/']},
       {'date': ['03 DE AGOSTO DE 2015'],
        'address': ['calle Benito Juarez esquina Riva Palacio, colonia Lomas de Chocolín'],
        'link': ['https://afondoedomex.com/zona-oriente/rescatan-a-mujer-secuestrada-y-violada-en-casa-de-seguridad-de-chimalhuacan/']},
      {'date': ['1 DE JULIO DEL 2015'],
       'address': ['calle Guadalupe Victoria, San Lucas Patoni, Tlalnepantla'],
       'link': ['https://afondoedomex.com/valle-de-mexico/secuestrado-escapa-por-una-ventana-de-casa-de-seguridad-en-tlalnepantla-detienen-a-5/']},
      {'date': ['06 DE MAYO DEL 2015'],
       'address': ['calle Gregorio Aguilar, colonia Cuauhtémoc, municipio de Axapusco, Estado de México'],
       'link': ['https://afondoedomex.com/zona-oriente/rescatan-a-103-indocumentados-secuestrados-en-casa-de-seguridad-en-edomex/']},
      {'date': ['9 DE DICIEMBRE DE 2016'],
       'address': ['calle Girasoles, esquina con Azucena, Flores, Ecatepec'],
       'link': ['https://afondoedomex.com/zona-oriente/jovencita-secuestrada-hace-una-semana-logra-escapar-de-casa-de-seguridad-en-ecatepec/']},
      {'date': ['3 DE OCTUBRE DEL 2014'],
       'address': ['número 103 de calle Cali, en Las Américas'],
       'link': ['https://afondoedomex.com/valle-de-mexico/joven-secuestrado-escapa-de-casa-de-seguridad-en-naucalpan-y-detienen-a-tres-plagiarios/']},
      {'date': ['12 de Febrero, 2018'],
       'address': ['colonia San Ángel, municipio de Matamoros'],
       'link': ['http://www.eluniversal.com.mx/estados/aseguran-44-migrantes-en-otra-casa-en-matamoros']},
      {'date': ['FEBRERO 02, 2018'],
       'address': ['Avenida Fonatur, manzana 16, Supermanzana 523, Cancún, México'],
       'link': ['http://noticaribe.com.mx/2018/02/02/catean-casa-de-seguridad-en-cancun-detienen-a-una-persona-y-aseguran-vehiculos-en-presunto-golpe-contra-red-de-trata-de-blancas-pero-aun-no-hay-confirmacion/']},
      {'date': ['03, Febrero 2018'],'address': ['colonia San Marcos, municipio de Loreto, Zacatecas'],
       'link': ['https://zacatecasonline.com.mx/noticias/policia/62291-armas-casa-seguridad-loreto']},
      {'date': ['12/02/2018'],
       'address': ['colonia San Ángel, ciudad de Matamoros, Tamaulipas'],
       'link': ['http://www.eluniversal.com.mx/estados/aseguran-44-migrantes-en-otra-casa-en-matamoros']},
      {'date': ['10/02/2018'],
       'address': ['avenida Fonatur, en la Supermanzana 523, Cancún'],
       'link': ['http://www.eluniversal.com.mx/estados/acusan-federales-de-robo-y-abuso-durante-operativo-antitrata-en-cancun']}]

df_main = pd.DataFrame(data=data)
#df['id'] = df.index
df_main.reset_index(inplace=True)
#df.reset_index()
df_main
# Out:
#     index                                            address  \
# 0       0  [calle Yuriria, de la manzana 26, lote 12, en ...
# 1       1  [calle Benito Juarez esquina Riva Palacio, col...
# 2       2  [calle Guadalupe Victoria, en San Lucas Patoni...
# 3       3  [número 27 de la calle Gregorio Aguilar en la ...
# 4       4  [calle Girasoles, esquina con Azucena, en el n...
# 5       5  [número 103 de calle Cali, en Las Américas, Va...
# 6       6        [colonia San Ángel, municipio de Matamoros]
# 7       7  [Avenida Fonatur, en la manzana 16, de la Supe...
# 8       8  [colonia San Marcos, municipio de Loreto, Zaca...
# 9       9  [colonia San Ángel, ciudad de Matamoros, Tamau...
# 10     10  [avenida Fonatur, en la Supermanzana 523, Cancún]
#
#                         date  \
# 0     [19 DE AGOSTO DE 2015]
# 1     [03 DE AGOSTO DE 2015]
# 2      [1 DE JULIO DEL 2015]
# 3      [06 DE MAYO DEL 2015]
# 4   [9 DE DICIEMBRE DE 2016]
# 5    [3 DE OCTUBRE DEL 2014]
# 6      [12 de Febrero, 2018]
# 7         [FEBRERO 02, 2018]
# 8         [03, Febrero 2018]
# 9               [12/02/2018]
# 10              [10/02/2018]
#
#                                                  link
# 0   [https://afondoedomex.com/zona-oriente/secuest...
# 1   [https://afondoedomex.com/zona-oriente/rescata...
# 2   [https://afondoedomex.com/valle-de-mexico/secu...
# 3   [https://afondoedomex.com/zona-oriente/rescata...
# 4   [https://afondoedomex.com/zona-oriente/jovenci...
# 5   [https://afondoedomex.com/valle-de-mexico/jove...
# 6   [https://afondoedomex.com/valle-de-mexico/jove...
# 7   [http://noticaribe.com.mx/2018/02/02/catean-ca...
# 8   [https://zacatecasonline.com.mx/noticias/polic...
# 9   [http://www.eluniversal.com.mx/estados/asegura...
# 10  [http://www.eluniversal.com.mx/estados/acusan-...

# %%
def address_to_location(address, key):
    import requests

    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'

    params = {
        'address': address, #'calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac',
        'sensor': 'false',
        'key': key #'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'
    }

    # Do the request and get the response data
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)
    res = req.json()

    # Use the first result
    result = res['results'][0]

    geodata = dict()
    geodata['lat'] = result['geometry']['location']['lat']
    geodata['lng'] = result['geometry']['location']['lng']
    geodata['address'] = result['formatted_address']
    
    #res['results'][0]['geometry']['location']
    #r = geodata['address']

    #print('{address}. (lat, lng) = ({lat}, {lng})'.format(**geodata))
    # 221B Baker Street, London, Greater London NW1 6XE, UK. (lat, lng) = (51.5237038, -0.1585531)
    

    return (geodata['address'], {'lat':geodata['lat'], 'lng': geodata['lng']})

# %%
address_to_location('calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac', 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME')
# Out:
# ('Valle de Yuriria 26, Fuentes de Aragón, 55210 Ecatepec de Morelos, Méx., Mexico',
#  {'lat': 19.5179648, 'lng': -99.0273843})

# %%
def location_to_nearby_places(location, radius, key):        
    import requests
    
    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

    params = {
        'location': location,#'19.5179648, -99.0273843', #'19.5179648, -99.0273843', #'calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac',
        'radius': radius,
        'key': key
    }

    # Do the request and get the response data
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)
    res = req.json()

    df = pd.DataFrame(res['results'])
    df_copy = df.copy()
    df_copy.reset_index(inplace=True)

    df_geometry = pd.DataFrame(columns=['index', 'location', 'lat', 'lng'])

    for line in range(len(df_copy['geometry'])):
        location = df_copy['geometry'][line]
        df_geometry = df_geometry.append({'index': line,
                                          'location': location.get('location'),
                                          'lat': location.get('location').get('lat'), 
                                          'lng': location.get('location').get('lng')}, ignore_index=True)

    df_selected= pd.DataFrame()
    df_selected = pd.merge(left=df_copy, right=df_geometry, how='outer', )
    df_selected = df_selected[['name', 'types', 'vicinity', 'location', 'lat', 'lng']]

    df_selected

    return df_selected

# %%
location_to_nearby_places('19.5179648, -99.0273843', '500', 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME')
# Out:
#                                         name  \
# 0                                   Ecatepec
# 1           Municipio de Ecatepec de Morelos
# 2      Centro Educativo Frida Kahlo Ecatepec
# 3   AH DISEÑOS Sillas y Muebles para Oficina
# 4                      Distribuidora Medivet
# 5            Recubrimientos Integrales Delta
# 6                                   Dacoemex
# 7                      Ramirez Racing Taller
# 8             ASESORES JURÍDICOS FRUTIS S.C.
# 9                                       Hsbc
# 10                      Simon Bolivar School
# 11             Boneless & Alitas "The House"
# 12                   AUTOELECTRICA LA CORONA
# 13                      Simón Bolivar school
# 14                     Farmacia De Similares
# 15                          FARMACIA CAMARAS
# 16                          FARMACIA 24 hrs.
# 17                   Vidrio y Aluminio Altea
# 18                                   FASHION
# 19                         Fuentes de Aragón
#
#                                                 types  \
# 0                               [locality, political]
# 1   [local_government_office, point_of_interest, e...
# 2          [school, point_of_interest, establishment]
# 3   [furniture_store, home_goods_store, store, poi...
# 4                  [point_of_interest, establishment]
# 5                  [point_of_interest, establishment]
# 6                  [point_of_interest, establishment]
# 7      [car_repair, point_of_interest, establishment]
# 8          [lawyer, point_of_interest, establishment]
# 9   [shopping_mall, point_of_interest, establishment]
# 10         [school, point_of_interest, establishment]
# 11  [restaurant, food, point_of_interest, establis...
# 12                 [point_of_interest, establishment]
# 13         [school, point_of_interest, establishment]
# 14  [pharmacy, store, health, point_of_interest, e...
# 15  [pharmacy, store, health, point_of_interest, e...
# 16  [pharmacy, store, health, point_of_interest, e...
# 17  [general_contractor, point_of_interest, establ...
# 18   [beauty_salon, point_of_interest, establishment]
# 19      [sublocality_level_1, sublocality, political]
#
#                                              vicinity  \
# 0                                 Ecatepec de Morelos
# 1   16 de Septiembre Sn, Rinconada de Aragón, Ecat...
# 2   Josefa Ortiz de Domínguez Mz.16 Lt.14, 16 de S...
# 3   Valle de Teotihuacan 55, Fuentes de Aragón, Ec...
# 4   Avenida Vicente Guerrero Manzana 7, Poesía Mex...
# 5             16 de Septiembre 42, Centro, Polotitlán
# 6   Valle de Yuriria 7757, Fuentes de Aragón, Ecat...
# 7   Ignacio Allende 7, Ecatepec Edo. De Mex., 16 d...
# 8              Fuentes de Aragón, Ecatepec de Morelos
# 9               16 de Septiembre, Ecatepec de Morelos
# 10  Orquídeas, Jardines de Aragon, Ecatepec de Mor...
# 11  55170, Avenida Vicente Guerrero 43, 16 de Sept...
# 12  Valle de Sagitario esquina Tulum, Fuentes de A...
# 13  Valle de Sagitario 33, Jardines de Aragón, Eca...
# 14             Fuentes de Aragón, Ecatepec de Morelos
# 15  Violetas Mz 31 Lt 26, Jardines de Aragon, Ecat...
# 16  Valle de Sagitario & Violetas, Fuentes de Arag...
# 17  Av. Miguel Hidalgo Mza. A Lt. 3, Tolotzin 2, E...
# 18  Entre Jóse María Morelos y Josefa Ortiz de Dom...
# 19                                  Fuentes de Aragón
#
#                                              location        lat        lng
# 0       {'lat': 19.601841, 'lng': -99.05067439999999}  19.601841 -99.050674
# 1             {'lat': 19.5186068, 'lng': -99.0260963}  19.518607 -99.026096
# 2             {'lat': 19.5163931, 'lng': -99.0257376}  19.516393 -99.025738
# 3             {'lat': 19.5174395, 'lng': -99.0302614}  19.517439 -99.030261
# 4             {'lat': 19.5180336, 'lng': -99.0263032}  19.518034 -99.026303
# 5      {'lat': 19.5166327, 'lng': -99.02502369999999}  19.516633 -99.025024
# 6      {'lat': 19.5169668, 'lng': -99.02780140000002}  19.516967 -99.027801
# 7       {'lat': 19.517494, 'lng': -99.02597999999999}  19.517494 -99.025980
# 8               {'lat': 19.516615, 'lng': -99.028443}  19.516615 -99.028443
# 9      {'lat': 19.5183869, 'lng': -99.02613690000001}  19.518387 -99.026137
# 10            {'lat': 19.5190995, 'lng': -99.0266791}  19.519099 -99.026679
# 11            {'lat': 19.5167091, 'lng': -99.0269709}  19.516709 -99.026971
# 12     {'lat': 19.5192605, 'lng': -99.02770699999999}  19.519261 -99.027707
# 13            {'lat': 19.5191633, 'lng': -99.0267441}  19.519163 -99.026744
# 14            {'lat': 19.5193014, 'lng': -99.0279203}  19.519301 -99.027920
# 15              {'lat': 19.518983, 'lng': -99.026207}  19.518983 -99.026207
# 16  {'lat': 19.51879479999999, 'lng': -99.02595799...  19.518795 -99.025958
# 17     {'lat': 19.5188301, 'lng': -99.02577579999999}  19.518830 -99.025776
# 18            {'lat': 19.5183394, 'lng': -99.0252055}  19.518339 -99.025205
# 19            {'lat': 19.5166635, 'lng': -99.0308525}  19.516663 -99.030852

# %%
key = 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'
radius = '500'

address, geometry =  address_to_location('calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac', key)

lat, lng = list(geometry.values())

location = repr(lat)+','+repr(lng)

location_to_nearby_places(location, radius, key).head()
# Out:
#                                        name  \
# 0                                  Ecatepec
# 1          Municipio de Ecatepec de Morelos
# 2     Centro Educativo Frida Kahlo Ecatepec
# 3  AH DISEÑOS Sillas y Muebles para Oficina
# 4                     Distribuidora Medivet
#
#                                                types  \
# 0                              [locality, political]
# 1  [local_government_office, point_of_interest, e...
# 2         [school, point_of_interest, establishment]
# 3  [furniture_store, home_goods_store, store, poi...
# 4                 [point_of_interest, establishment]
#
#                                             vicinity  \
# 0                                Ecatepec de Morelos
# 1  16 de Septiembre Sn, Rinconada de Aragón, Ecat...
# 2  Josefa Ortiz de Domínguez Mz.16 Lt.14, 16 de S...
# 3  Valle de Teotihuacan 55, Fuentes de Aragón, Ec...
# 4  Avenida Vicente Guerrero Manzana 7, Poesía Mex...
#
#                                         location        lat        lng
# 0  {'lat': 19.601841, 'lng': -99.05067439999999}  19.601841 -99.050674
# 1        {'lat': 19.5186068, 'lng': -99.0260963}  19.518607 -99.026096
# 2        {'lat': 19.5163931, 'lng': -99.0257376}  19.516393 -99.025738
# 3        {'lat': 19.5174395, 'lng': -99.0302614}  19.517439 -99.030261
# 4        {'lat': 19.5180336, 'lng': -99.0263032}  19.518034 -99.026303

# %%
key = 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'
radius = '500'

df_armed = pd.DataFrame(columns=['name', 'types', 'vicinity', 'location', 'lat', 'lng'])

df_main_copy = df_main.copy()
for line in df_main_copy['address']:
#    print(line[0])
    try:
        address_copy, geometry_copy =  address_to_location(line[0], key)
#        print(geometry_copy)
        lat, lng = list(geometry.values())
        location = repr(lat)+','+repr(lng)

        try:
            print(location)
            df_armed = df_armed.append(location_to_nearby_places(location, radius, key))
        
        except:
            pass
    except: 
        pass
#    print(location_to_nearby_places(line[0], radius, key))
df_armed
# Out:
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
# 19.5330056,-99.1608158
#                                                name  \
# 0                                       Mexico City
# 1   Quebradoras Molinos y Mezcladoras Lasser Kenito
# 2                    Escuela de Sastrería Artesanal
# 3                  Tortas y Tacos de Canasta "Andy"
# 4                                  Lecheria Liconsa
# 5                                              OXXO
# 6                                 Farmacia Nacional
# 7                                              Cari
# 8                                    Farmacia Diana
# 9                          Galvanolyte S.A. de C.V.
# 10                                    La Michoacana
# 11                                           Azteca
# 12                               Farmacia San Lucas
# 13                                      La Generosa
# 14                                     Farmacias Gi
# 15                                           TELMEX
# 16                       PALOMA balloon decorations
# 17                                    Farmacia Lily
# 18           Distribuidor Autorizado Telcel Digital
# 19                              Tlalnepantla de Baz
# 0                                       Mexico City
# 1   Quebradoras Molinos y Mezcladoras Lasser Kenito
# 2                    Escuela de Sastrería Artesanal
# 3                  Tortas y Tacos de Canasta "Andy"
# 4                                  Lecheria Liconsa
# 5                                              OXXO
# 6                                 Farmacia Nacional
# 7                                              Cari
# 8                                    Farmacia Diana
# 9                          Galvanolyte S.A. de C.V.
# ..                                              ...
# 10                                    La Michoacana
# 11                                           Azteca
# 12                               Farmacia San Lucas
# 13                                      La Generosa
# 14                                     Farmacias Gi
# 15                                           TELMEX
# 16                       PALOMA balloon decorations
# 17                                    Farmacia Lily
# 18           Distribuidor Autorizado Telcel Digital
# 19                              Tlalnepantla de Baz
# 0                                       Mexico City
# 1   Quebradoras Molinos y Mezcladoras Lasser Kenito
# 2                    Escuela de Sastrería Artesanal
# 3                  Tortas y Tacos de Canasta "Andy"
# 4                                  Lecheria Liconsa
# 5                                              OXXO
# 6                                 Farmacia Nacional
# 7                                              Cari
# 8                                    Farmacia Diana
# 9                          Galvanolyte S.A. de C.V.
# 10                                    La Michoacana
# 11                                           Azteca
# 12                               Farmacia San Lucas
# 13                                      La Generosa
# 14                                     Farmacias Gi
# 15                                           TELMEX
# 16                       PALOMA balloon decorations
# 17                                    Farmacia Lily
# 18           Distribuidor Autorizado Telcel Digital
# 19                              Tlalnepantla de Baz
#
#                                                 types  \
# 0                               [locality, political]
# 1                  [point_of_interest, establishment]
# 2          [school, point_of_interest, establishment]
# 3   [restaurant, food, point_of_interest, establis...
# 4            [food, point_of_interest, establishment]
# 5   [grocery_or_supermarket, store, food, point_of...
# 6   [pharmacy, store, health, point_of_interest, e...
# 7            [food, point_of_interest, establishment]
# 8   [pharmacy, store, health, point_of_interest, e...
# 9                  [point_of_interest, establishment]
# 10    [store, food, point_of_interest, establishment]
# 11        [laundry, point_of_interest, establishment]
# 12  [pharmacy, store, health, point_of_interest, e...
# 13  [pharmacy, store, health, point_of_interest, e...
# 14  [pharmacy, store, health, point_of_interest, e...
# 15                 [point_of_interest, establishment]
# 16                 [point_of_interest, establishment]
# 17  [pharmacy, store, health, point_of_interest, e...
# 18                 [point_of_interest, establishment]
# 19                              [locality, political]
# 0                               [locality, political]
# 1                  [point_of_interest, establishment]
# 2          [school, point_of_interest, establishment]
# 3   [restaurant, food, point_of_interest, establis...
# 4            [food, point_of_interest, establishment]
# 5   [grocery_or_supermarket, store, food, point_of...
# 6   [pharmacy, store, health, point_of_interest, e...
# 7            [food, point_of_interest, establishment]
# 8   [pharmacy, store, health, point_of_interest, e...
# 9                  [point_of_interest, establishment]
# ..                                                ...
# 10    [store, food, point_of_interest, establishment]
# 11        [laundry, point_of_interest, establishment]
# 12  [pharmacy, store, health, point_of_interest, e...
# 13  [pharmacy, store, health, point_of_interest, e...
# 14  [pharmacy, store, health, point_of_interest, e...
# 15                 [point_of_interest, establishment]
# 16                 [point_of_interest, establishment]
# 17  [pharmacy, store, health, point_of_interest, e...
# 18                 [point_of_interest, establishment]
# 19                              [locality, political]
# 0                               [locality, political]
# 1                  [point_of_interest, establishment]
# 2          [school, point_of_interest, establishment]
# 3   [restaurant, food, point_of_interest, establis...
# 4            [food, point_of_interest, establishment]
# 5   [grocery_or_supermarket, store, food, point_of...
# 6   [pharmacy, store, health, point_of_interest, e...
# 7            [food, point_of_interest, establishment]
# 8   [pharmacy, store, health, point_of_interest, e...
# 9                  [point_of_interest, establishment]
# 10    [store, food, point_of_interest, establishment]
# 11        [laundry, point_of_interest, establishment]
# 12  [pharmacy, store, health, point_of_interest, e...
# 13  [pharmacy, store, health, point_of_interest, e...
# 14  [pharmacy, store, health, point_of_interest, e...
# 15                 [point_of_interest, establishment]
# 16                 [point_of_interest, establishment]
# 17  [pharmacy, store, health, point_of_interest, e...
# 18                 [point_of_interest, establishment]
# 19                              [locality, political]
#
#                                              vicinity  \
# 0                                         Mexico City
# 1           Peñitas 2, San Lucas Patoni, Tlalnepantla
# 2      Mariano Escobedo 61 Altos, Centro, Tlanepantla
# 3   Mercado Adolfo López Mateos, Guadalupe Victori...
# 4   Guadalupe Victoria SN, San Lucas Patoni, Tlaln...
# 5   Tlalnepantla de Baz,, Avenida Benito Juárez 36...
# 6   Avenida Benito Juárez 32, San Lucas Patoni, Tl...
# 7   Calle Felipe Angeles 47, San Lucas Patoni, Tla...
# 8   Avenida Benito Juárez 43-1, San Lucas Patoni, ...
# 9   Calle Felipe Angeles 53, San Lucas Patoni, Tla...
# 10                                             Mexico
# 11  Calle Felipe Angeles 58, San Lucas Patoni, Tla...
# 12  Calle Felipe Angeles 59, San Lucas Patoni, Tla...
# 13                                             Mexico
# 14    Ricardo Flores Magón, Las Palomas, Tlalnepantla
# 15  Avenida Benito Juárez 22B, San Lucas Patoni, C...
# 16          Aquiles Serdán, Las Palomas, Tlalnepantla
# 17  Calle Felipe Angeles 28, Las Palomas, Tlalnepa...
# 18  Avenida Benito Juárez 4, San Lucas Patoni, Tla...
# 19                                Tlalnepantla de Baz
# 0                                         Mexico City
# 1           Peñitas 2, San Lucas Patoni, Tlalnepantla
# 2      Mariano Escobedo 61 Altos, Centro, Tlanepantla
# 3   Mercado Adolfo López Mateos, Guadalupe Victori...
# 4   Guadalupe Victoria SN, San Lucas Patoni, Tlaln...
# 5   Tlalnepantla de Baz,, Avenida Benito Juárez 36...
# 6   Avenida Benito Juárez 32, San Lucas Patoni, Tl...
# 7   Calle Felipe Angeles 47, San Lucas Patoni, Tla...
# 8   Avenida Benito Juárez 43-1, San Lucas Patoni, ...
# 9   Calle Felipe Angeles 53, San Lucas Patoni, Tla...
# ..                                                ...
# 10                                             Mexico
# 11  Calle Felipe Angeles 58, San Lucas Patoni, Tla...
# 12  Calle Felipe Angeles 59, San Lucas Patoni, Tla...
# 13                                             Mexico
# 14    Ricardo Flores Magón, Las Palomas, Tlalnepantla
# 15  Avenida Benito Juárez 22B, San Lucas Patoni, C...
# 16          Aquiles Serdán, Las Palomas, Tlalnepantla
# 17  Calle Felipe Angeles 28, Las Palomas, Tlalnepa...
# 18  Avenida Benito Juárez 4, San Lucas Patoni, Tla...
# 19                                Tlalnepantla de Baz
# 0                                         Mexico City
# 1           Peñitas 2, San Lucas Patoni, Tlalnepantla
# 2      Mariano Escobedo 61 Altos, Centro, Tlanepantla
# 3   Mercado Adolfo López Mateos, Guadalupe Victori...
# 4   Guadalupe Victoria SN, San Lucas Patoni, Tlaln...
# 5   Tlalnepantla de Baz,, Avenida Benito Juárez 36...
# 6   Avenida Benito Juárez 32, San Lucas Patoni, Tl...
# 7   Calle Felipe Angeles 47, San Lucas Patoni, Tla...
# 8   Avenida Benito Juárez 43-1, San Lucas Patoni, ...
# 9   Calle Felipe Angeles 53, San Lucas Patoni, Tla...
# 10                                             Mexico
# 11  Calle Felipe Angeles 58, San Lucas Patoni, Tla...
# 12  Calle Felipe Angeles 59, San Lucas Patoni, Tla...
# 13                                             Mexico
# 14    Ricardo Flores Magón, Las Palomas, Tlalnepantla
# 15  Avenida Benito Juárez 22B, San Lucas Patoni, C...
# 16          Aquiles Serdán, Las Palomas, Tlalnepantla
# 17  Calle Felipe Angeles 28, Las Palomas, Tlalnepa...
# 18  Avenida Benito Juárez 4, San Lucas Patoni, Tla...
# 19                                Tlalnepantla de Baz
#
#                                           location        lat        lng
# 0           {'lat': 19.4326077, 'lng': -99.133208}  19.432608 -99.133208
# 1            {'lat': 19.534105, 'lng': -99.160128}  19.534105 -99.160128
# 2          {'lat': 19.5322089, 'lng': -99.1576903}  19.532209 -99.157690
# 3          {'lat': 19.5330667, 'lng': -99.1610983}  19.533067 -99.161098
# 4          {'lat': 19.5329532, 'lng': -99.1612746}  19.532953 -99.161275
# 5           {'lat': 19.5333207, 'lng': -99.161248}  19.533321 -99.161248
# 6          {'lat': 19.5332351, 'lng': -99.1614409}  19.533235 -99.161441
# 7          {'lat': 19.5325469, 'lng': -99.1602145}  19.532547 -99.160214
# 8   {'lat': 19.5337618, 'lng': -99.16047359999999}  19.533762 -99.160474
# 9   {'lat': 19.5332422, 'lng': -99.15987179999999}  19.533242 -99.159872
# 10         {'lat': 19.5324992, 'lng': -99.1617112}  19.532499 -99.161711
# 11  {'lat': 19.5334313, 'lng': -99.15957069999999}  19.533431 -99.159571
# 12         {'lat': 19.5336029, 'lng': -99.1595442}  19.533603 -99.159544
# 13         {'lat': 19.5339012, 'lng': -99.1591228}  19.533901 -99.159123
# 14   {'lat': 19.532287, 'lng': -99.15890300000001}  19.532287 -99.158903
# 15  {'lat': 19.5340003, 'lng': -99.15903200000001}  19.534000 -99.159032
# 16           {'lat': 19.531674, 'lng': -99.159281}  19.531674 -99.159281
# 17         {'lat': 19.5311456, 'lng': -99.1600155}  19.531146 -99.160016
# 18         {'lat': 19.5329015, 'lng': -99.1631132}  19.532902 -99.163113
# 19  {'lat': 19.5345279, 'lng': -99.19073639999999}  19.534528 -99.190736
# 0           {'lat': 19.4326077, 'lng': -99.133208}  19.432608 -99.133208
# 1            {'lat': 19.534105, 'lng': -99.160128}  19.534105 -99.160128
# 2          {'lat': 19.5322089, 'lng': -99.1576903}  19.532209 -99.157690
# 3          {'lat': 19.5330667, 'lng': -99.1610983}  19.533067 -99.161098
# 4          {'lat': 19.5329532, 'lng': -99.1612746}  19.532953 -99.161275
# 5           {'lat': 19.5333207, 'lng': -99.161248}  19.533321 -99.161248
# 6          {'lat': 19.5332351, 'lng': -99.1614409}  19.533235 -99.161441
# 7          {'lat': 19.5325469, 'lng': -99.1602145}  19.532547 -99.160214
# 8   {'lat': 19.5337618, 'lng': -99.16047359999999}  19.533762 -99.160474
# 9   {'lat': 19.5332422, 'lng': -99.15987179999999}  19.533242 -99.159872
# ..                                             ...        ...        ...
# 10         {'lat': 19.5324992, 'lng': -99.1617112}  19.532499 -99.161711
# 11  {'lat': 19.5334313, 'lng': -99.15957069999999}  19.533431 -99.159571
# 12         {'lat': 19.5336029, 'lng': -99.1595442}  19.533603 -99.159544
# 13         {'lat': 19.5339012, 'lng': -99.1591228}  19.533901 -99.159123
# 14   {'lat': 19.532287, 'lng': -99.15890300000001}  19.532287 -99.158903
# 15  {'lat': 19.5340003, 'lng': -99.15903200000001}  19.534000 -99.159032
# 16           {'lat': 19.531674, 'lng': -99.159281}  19.531674 -99.159281
# 17         {'lat': 19.5311456, 'lng': -99.1600155}  19.531146 -99.160016
# 18         {'lat': 19.5329015, 'lng': -99.1631132}  19.532902 -99.163113
# 19  {'lat': 19.5345279, 'lng': -99.19073639999999}  19.534528 -99.190736
# 0           {'lat': 19.4326077, 'lng': -99.133208}  19.432608 -99.133208
# 1            {'lat': 19.534105, 'lng': -99.160128}  19.534105 -99.160128
# 2          {'lat': 19.5322089, 'lng': -99.1576903}  19.532209 -99.157690
# 3          {'lat': 19.5330667, 'lng': -99.1610983}  19.533067 -99.161098
# 4          {'lat': 19.5329532, 'lng': -99.1612746}  19.532953 -99.161275
# 5           {'lat': 19.5333207, 'lng': -99.161248}  19.533321 -99.161248
# 6          {'lat': 19.5332351, 'lng': -99.1614409}  19.533235 -99.161441
# 7          {'lat': 19.5325469, 'lng': -99.1602145}  19.532547 -99.160214
# 8   {'lat': 19.5337618, 'lng': -99.16047359999999}  19.533762 -99.160474
# 9   {'lat': 19.5332422, 'lng': -99.15987179999999}  19.533242 -99.159872
# 10         {'lat': 19.5324992, 'lng': -99.1617112}  19.532499 -99.161711
# 11  {'lat': 19.5334313, 'lng': -99.15957069999999}  19.533431 -99.159571
# 12         {'lat': 19.5336029, 'lng': -99.1595442}  19.533603 -99.159544
# 13         {'lat': 19.5339012, 'lng': -99.1591228}  19.533901 -99.159123
# 14   {'lat': 19.532287, 'lng': -99.15890300000001}  19.532287 -99.158903
# 15  {'lat': 19.5340003, 'lng': -99.15903200000001}  19.534000 -99.159032
# 16           {'lat': 19.531674, 'lng': -99.159281}  19.531674 -99.159281
# 17         {'lat': 19.5311456, 'lng': -99.1600155}  19.531146 -99.160016
# 18         {'lat': 19.5329015, 'lng': -99.1631132}  19.532902 -99.163113
# 19  {'lat': 19.5345279, 'lng': -99.19073639999999}  19.534528 -99.190736
#
# [160 rows x 6 columns]

# %%
#df_armed.reset_index(inplace=True)
df_type_place = pd.DataFrame(columns=['types'])

for type_place in df_armed['types']:    
#    print(type_place[0])
    df_type_place = df_type_place.append({'types': type_place[0]}, ignore_index=True) 
#df_armed['types']
#df_type_place.head()
df_type_place.groupby(df_type_place.types.astype('category')).count()
# Out:
#                         types
# types
# food                       16
# grocery_or_supermarket      8
# laundry                     8
# locality                   16
# pharmacy                   48
# point_of_interest          40
# restaurant                  8
# school                      8
# store                       8
