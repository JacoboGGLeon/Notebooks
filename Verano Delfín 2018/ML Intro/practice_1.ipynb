# %% [markdown]
# Dipanjan Sarkar, Raghav Bali, Tushar Sharma - Practical Machine Learning with Python - Apress (2018).pdf
#
# http://datamx.io/dataset/delitos-del-fuero-comun
#
# JSON Formatter

# %% [markdown]
# # Processing, Wrangling and Visualizing Data

# %% [markdown]
# ## CRISP-DM methodology.
#
# It is one of the standard workflows followed by Data Science teams across the world. We will concentrate on the following sub-sections of this methodology:
# * Data collection: To understand different data retrieval mechanisms for different data types
# * Data description: To understand various attributes and properties of the data collected
# * Data wrangling: To prepare data for consumption in the modeling steps
# * Data visualization: To visualize different attributes for sharing results, better
# understanding, and so on

# %% [markdown]
# ### Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
# https://datos.gob.mx/busca/dataset/numero-de-jornales-pagados
# path = '/Users/jacoboleon/Downloads/Empleo_Temporal_Jornales.csv'

# http://datamx.io/dataset/delitos-del-fuero-comun
path = '../../../Datasets/fuerocomunmunicipios.csv'
df = pd.read_csv(path, encoding='latin', low_memory=False)
df.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %% [markdown]
# General Stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5740636 entries, 0 to 5740635
# Data columns (total 10 columns):
# state_code    int64
# mun_code      int64
# year          int64
# month         int64
# crime         object
# category      object
# type          object
# subtype       object
# count         float64
# population    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 438.0+ MB

# %% [markdown]
# Shape of dataframe

# %%
df.shape
# Out:
# (5740636, 10)

# %% [markdown]
# Number of rows

# %%
df.shape[0]
# Out:
# 5740636

# %% [markdown]
# Number of columns

# %%
df.shape[1]
# Out:
# Number of columns:
# 10

# %% [markdown]
# Column Names

# %%
df.columns.values.tolist()
# Out:
# ['state_code',
#  'mun_code',
#  'year',
#  'month',
#  'crime',
#  'category',
#  'type',
#  'subtype',
#  'count',
#  'population']

# %% [markdown]
# Column Data Types

# %%
df.dtypes
# Out:
# state_code      int64
# mun_code        int64
# year            int64
# month           int64
# crime          object
# category       object
# type           object
# subtype        object
# count         float64
# population      int64
# dtype: object

# %% [markdown]
# Columns with Missing Values

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['count']

# %% [markdown]
# Number of rows with Missing Values

# %%
len(pd.isnull(df).any(1).nonzero()[0].tolist())
# Out:
# 3414383

# %% [markdown]
# Sample Indices with missing data

# %%
pd.isnull(df).any(1).nonzero()[0].tolist()[0:5]
# Out:
# [941, 946, 2661, 2741, 2781]

# %% [markdown]
# Summary Stats

# %%
df.describe()
# Out:
#          state_code      mun_code          year         month         count  \
# count  5.740636e+06  5.740636e+06  5.740636e+06  5.740636e+06  2.326253e+06
# mean   1.899102e+01  9.452533e+01  2.012263e+03  6.004696e+00  2.308071e+00
# std    7.608523e+00  1.188232e+02  9.405606e-01  3.479479e+00  1.984210e+01
# min    1.000000e+00  1.000000e+00  2.011000e+03  1.000000e+00  0.000000e+00
# 25%    1.400000e+01  2.100000e+01  2.012000e+03  3.000000e+00  0.000000e+00
# 50%    2.000000e+01  5.100000e+01  2.012000e+03  6.000000e+00  0.000000e+00
# 75%    2.400000e+01  1.090000e+02  2.013000e+03  9.000000e+00  0.000000e+00
# max    3.200000e+01  5.700000e+02  2.014000e+03  1.200000e+01  3.778000e+03
#
#          population
# count  5.740636e+06
# mean   5.235490e+04
# std    1.450224e+05
# min    9.000000e+01
# 25%    5.329000e+03
# 50%    1.491100e+04
# 75%    3.693200e+04
# max    1.830454e+06

# %% [markdown]
# Select specific row index

# %%
df.loc[[0]]
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
#
#    population
# 0      811483

# %% [markdown]
# Select specific row indices

# %%
df.loc[30:33]
# Out:
#     state_code  mun_code  year  month                  crime  \
# 30           1         1  2013      7  DELITOS PATRIMONIALES
# 31           1         1  2013      8  DELITOS PATRIMONIALES
# 32           1         1  2013      9  DELITOS PATRIMONIALES
# 33           1         1  2013     10  DELITOS PATRIMONIALES
#
#                  category                type             subtype  count  \
# 30  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   47.0
# 31  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   48.0
# 32  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   39.0
# 33  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   42.0
#
#     population
# 30      842391
# 31      843374
# 32      844358
# 33      845341

# %% [markdown]
# Excluding Specific Row indices

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
# 5           1         1  2011      6  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
# 5  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
#
#    population
# 1      812551
# 2      813619
# 3      814686
# 4      815754
# 5      816822

# %% [markdown]
# Excluding Specific Range Row indices

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     state_code  mun_code  year  month                  crime  \
# 0            1         1  2011      1  DELITOS PATRIMONIALES
# 5            1         1  2011      6  DELITOS PATRIMONIALES
# 6            1         1  2011      7  DELITOS PATRIMONIALES
# 7            1         1  2011      8  DELITOS PATRIMONIALES
# 8            1         1  2011      9  DELITOS PATRIMONIALES
# 9            1         1  2011     10  DELITOS PATRIMONIALES
# 10           1         1  2011     11  DELITOS PATRIMONIALES
# 11           1         1  2011     12  DELITOS PATRIMONIALES
# 12           1         1  2012      1  DELITOS PATRIMONIALES
# 13           1         1  2012      2  DELITOS PATRIMONIALES
#
#                  category                type             subtype  count  \
# 0   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 5   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# ...

# %% [markdown]
# Subsetting based on offset from top (bottom)

# %%
df[100:].head() #df.tail(-100) )
# Out:
#      state_code  mun_code  year  month                  crime  \
# 100           1         1  2012      9  DELITOS PATRIMONIALES
# 101           1         1  2012     10  DELITOS PATRIMONIALES
# 102           1         1  2012     11  DELITOS PATRIMONIALES
# 103           1         1  2012     12  DELITOS PATRIMONIALES
# 104           1         1  2013      1  DELITOS PATRIMONIALES
#
#                   category     type        subtype  count  population
# 100  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      832319
# 101  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      833329
# 102  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      834339
# 103  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      835348
# 104  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      836358

# %% [markdown]
# Get values for crime

# %%
df.crime.values
# Out:
# array(['DELITOS PATRIMONIALES', 'DELITOS PATRIMONIALES',
#        'DELITOS PATRIMONIALES', ..., 'ROBOS', 'ROBOS', 'ROBOS'], dtype=object)

# %%
df.crime.unique()
# Out:
# array(['DELITOS PATRIMONIALES', 'DELITOS SEXUALES', 'HOMICIDIOS',
#        'LESIONES', 'OTROS DELITOS', 'PRIV. DE LA LIBERTAD (SECUESTRO)',
#        'ROBOS'], dtype=object)

# %% [markdown]
# Get number of values for crime

# %%
df.crime.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          DELITOS PATRIMONIALES
# 1          DELITOS PATRIMONIALES
# 2          DELITOS PATRIMONIALES
# 3          DELITOS PATRIMONIALES
# 4          DELITOS PATRIMONIALES
# 5          DELITOS PATRIMONIALES
# 6          DELITOS PATRIMONIALES
# 7          DELITOS PATRIMONIALES
# 8          DELITOS PATRIMONIALES
# 9          DELITOS PATRIMONIALES
# 10         DELITOS PATRIMONIALES
# 11         DELITOS PATRIMONIALES
# 12         DELITOS PATRIMONIALES
# 13         DELITOS PATRIMONIALES
# 14         DELITOS PATRIMONIALES
# 15         DELITOS PATRIMONIALES
# 16         DELITOS PATRIMONIALES
# 17         DELITOS PATRIMONIALES
# 18         DELITOS PATRIMONIALES
# 19         DELITOS PATRIMONIALES
# 20         DELITOS PATRIMONIALES
# 21         DELITOS PATRIMONIALES
# 22         DELITOS PATRIMONIALES
# 23         DELITOS PATRIMONIALES
# 24         DELITOS PATRIMONIALES
# 25         DELITOS PATRIMONIALES
# 26         DELITOS PATRIMONIALES
# ...

# %% [markdown]
# Get the number of unique values for each column

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code     year    month    crime  category     type  \
# count       5740636   5740636  5740636  5740636  5740636   5740636  5740636
# size        5740636   5740636  5740636  5740636  5740636   5740636  5740636
# nunique          32       570        4       12        7        10       18
#
#          subtype    count  population
# count    5740636  2326253     5740636
# size     5740636  5740636     5740636
# nunique       29      889       46404

# %% [markdown]
# An `agg` within a `groupby`. And`stack` at the end.

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code    year   month   crime  category    type  \
# state_code
# 1          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# 2          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 3          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 4          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# ...

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique'])
# Out:
#            mun_code                    year                   month          \
#               count    size nunique   count    size nunique   count    size
# state_code
# 1             29040   29040      11   29040   29040       4   29040   29040
# 2             13200   13200       5   13200   13200       4   13200   13200
# 3             13200   13200       5   13200   13200       4   13200   13200
# 4             29040   29040      11   29040   29040       4   29040   29040
# 5            100320  100320      38  100320  100320       4  100320  100320
# 6             26400   26400      10   26400   26400       4   26400   26400
# 7            311520  311520     118  311520  311520       4  311520  311520
# 8            176880  176880      67  176880  176880       4  176880  176880
# 9             42108   42108      16   42108   42108       4   42108   42108
# 10           102960  102960      39  102960  102960       4  102960  102960
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          state_code  mun_code  year  month                             crime  \
# 5336858          30       205  2012      5                             ROBOS
# 4548928          27         7  2012      1                             ROBOS
# 547626            8        10  2013      3  PRIV. DE LA LIBERTAD (SECUESTRO)
# 2979568          20       235  2012      3                             ROBOS
# 2884258          20       180  2013     11                             ROBOS
#
#                                  category           type       subtype  count  \
# 5336858   ROBO EN INSTITUCIONES BANCARIAS  SIN VIOLENCIA         OTROS    NaN
# 4548928                        ROBO COMUN  SIN VIOLENCIA  DE VEHICULOS    0.0
# 547626   PRIV. DE LA LIBERTAD (SECUESTRO)      SECUESTRO     SECUESTRO    NaN
# 2979568   ROBO EN INSTITUCIONES BANCARIAS  SIN VIOLENCIA     SIN DATOS    NaN
# 2884258   ROBO EN INSTITUCIONES BANCARIAS  SIN VIOLENCIA         OTROS    NaN
#
#          population
# ...

# %%
df.shape
# Out:
# (5740636, 10)

# %%
df_sample.shape
# Out:
# (287032, 10)

# %%
df_sample.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code   year  month  crime  category   type  subtype  \
# state_code
# 1          count        1457   1457   1457   1457      1457   1457     1457
#            size         1457   1457   1457   1457      1457   1457     1457
#            nunique        11      4     12      7        10     18       29
# 2          count         655    655    655    655       655    655      655
#            size          655    655    655    655       655    655      655
#            nunique         5      4     12      7        10     18       29
# 3          count         664    664    664    664       664    664      664
#            size          664    664    664    664       664    664      664
#            nunique         5      4     12      7        10     18       29
# 4          count        1451   1451   1451   1451      1451   1451     1451
#            size         1451   1451   1451   1451      1451   1451     1451
# ...

# %% [markdown]
# ### Data Transform

# %% [markdown]
# Drop Rows with missing `count`

# %%
df_dropped = df.dropna(subset=['count'])
df_dropped.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
df_dropped.shape
# Out:
# (2326253, 10)

# %% [markdown]
# Copy of df

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
df_copy.shape
# Out:
# (5740636, 10)

# %% [markdown]
# Fill Missing count values with mean count
#
# * ffill() and bfill() functions copy forward the data from the previous row (forward fill) or copy the value from the next row (backward fill)

# %%
df_dropped['count'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['count'].mean()
# Out:
# 2.30807096218683

# %%
df_copy['count'].fillna(value=np.round(df['count'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code     year    month    crime  category     type  \
# count       5740636   5740636  5740636  5740636  5740636   5740636  5740636
# size        5740636   5740636  5740636  5740636  5740636   5740636  5740636
# nunique          32       570        4       12        7        10       18
#
#          subtype    count  population
# count    5740636  5740636     5740636
# size     5740636  5740636     5740636
# nunique       29      889       46404

# %% [markdown]
# ### Handling Categorical Data

# %%
list(df.crime.unique())
# Out:
# ['DELITOS PATRIMONIALES',
#  'DELITOS SEXUALES',
#  'HOMICIDIOS',
#  'LESIONES',
#  'OTROS DELITOS',
#  'PRIV. DE LA LIBERTAD (SECUESTRO)',
#  'ROBOS']

# %% [markdown]
# Create a dictionary

# %%
keys = list(df.crime.unique())
vals = range(1,8)
crime_map = dict(zip(keys, vals))
crime_map
# Out:
# {'DELITOS PATRIMONIALES': 1,
#  'DELITOS SEXUALES': 2,
#  'HOMICIDIOS': 3,
#  'LESIONES': 4,
#  'OTROS DELITOS': 5,
#  'PRIV. DE LA LIBERTAD (SECUESTRO)': 6,
#  'ROBOS': 7}

# %%
df_copy['crime_cat'] = df.crime.map(crime_map)
df_copy.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population  crime_cat
# 0      811483          1
# 1      812551          1
# 2      813619          1
# 3      814686          1
# 4      815754          1

# %%
list(df_copy.crime_cat.unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### Normalizing Values
# Attribute normalization is the process of standardizing the range of values of attributes
#
# Normalization is also called feature scaling
#
# There are various ways of scaling/normalizing features:
# * rescaling
# * standardization (or zero-mean unit variance)
# * unit scaling and many more.

# %%
from sklearn import preprocessing

df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalized['population'].values.reshape(-1,1))
df_normalized['population_norm'] = np_scaled.reshape(-1,1)
df_normalized.head()
# Out:
# /Users/jacoboleon/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# ...

# %% [markdown]
# ### Data Summarization
# Preparing a compact representation of raw data at hand
#
# Aggregation of data using different statistical, mathematical, and other methods. Summarization is helpful for visualization, compressing raw data, and better understanding of its attributes.

# %%
df['state_code'].mean()
# Out:
# 18.991024687856886

# %%
df['state_code'][df['month'] == 1].mean()
# Out:
# 19.240224509512238

# %%
df.groupby(['state_code', 'year']).count()
# Out:
#                  mun_code   month   crime  category    type  subtype  count  \
# state_code year
# 1          2011      8712    8712    8712      8712    8712     8712   8708
#            2012      8712    8712    8712      8712    8712     8712   8585
#            2013      8712    8712    8712      8712    8712     8712   8708
#            2014      2904    2904    2904      2904    2904     2904   2903
# 2          2011      3960    3960    3960      3960    3960     3960   1500
#            2012      3960    3960    3960      3960    3960     3960   1739
#            2013      3960    3960    3960      3960    3960     3960   1512
#            2014      1320    1320    1320      1320    1320     1320    641
# 3          2011      3960    3960    3960      3960    3960     3960   3960
#            2012      3960    3960    3960      3960    3960     3960   3960
#            2013      3960    3960    3960      3960    3960     3960   1660
# ...

# %%
df.groupby(['state_code', 'year']).count()
# Out:
#                  mun_code   month   crime  category    type  subtype  count  \
# state_code year
# 1          2011      8712    8712    8712      8712    8712     8712   8708
#            2012      8712    8712    8712      8712    8712     8712   8585
#            2013      8712    8712    8712      8712    8712     8712   8708
#            2014      2904    2904    2904      2904    2904     2904   2903
# 2          2011      3960    3960    3960      3960    3960     3960   1500
#            2012      3960    3960    3960      3960    3960     3960   1739
#            2013      3960    3960    3960      3960    3960     3960   1512
#            2014      1320    1320    1320      1320    1320     1320    641
# 3          2011      3960    3960    3960      3960    3960     3960   3960
#            2012      3960    3960    3960      3960    3960     3960   3960
#            2013      3960    3960    3960      3960    3960     3960   1660
# ...

# %%
df.groupby(['category', 'year'])[['crime', 'mun_code']].count()
# Out:
#                                         crime  mun_code
# category                         year
# DELITOS PATRIMONIALES            2011  151872    151872
#                                  2012  203140    203140
#                                  2013  195426    195426
#                                  2014   58366     58366
# DELITOS SEXUALES (VIOLACION)     2011   21696     21696
#                                  2012   29020     29020
#                                  2013   27918     27918
#                                  2014    8338      8338
# HOMICIDIOS                       2011  173628    173628
#                                  2012  232160    232160
#                                  2013  223344    223344
#                                  2014   66688     66688
# LESIONES                         2011  173664    173664
#                                  2012  232160    232160
#                                  2013  223344    223344
# ...

# %%
# variant-1: multiple aggregations on single attribute
df_sample.groupby(['category', 'year'])[['crime', 'mun_code']].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                                       mun_code
#                                            sum        mean count_nonzero
# category                         year
# DELITOS PATRIMONIALES            2011   406307   54.647882          7435
#                                  2012  1113769  108.809007         10236
#                                  2013  1038856  107.720448          9644
#                                  2014   297999  104.304865          2857
# DELITOS SEXUALES (VIOLACION)     2011    61266   54.701786          1120
#                                  2012   154505  105.752909          1461
#                                  2013   151283  108.136526          1399
#                                  2014    46499  106.162100           438
# HOMICIDIOS                       2011   478818   54.659589          8760
#                                  2012  1278098  109.491819         11673
#                                  2013  1184793  106.354847         11140
# ...

# %%
# variant-2: different aggregation functions for each attribute
df_sample.groupby(['category', 'year']).agg({'month':np.mean,'population':np.max})
# Out:
#                                           month  population
# category                         year
# DELITOS PATRIMONIALES            2011  6.526833     1830454
#                                  2012  6.426631     1819980
#                                  2013  6.234965     1813631
#                                  2014  2.341267     1807970
# DELITOS SEXUALES (VIOLACION)     2011  6.653571     1583012
#                                  2012  6.475702     1716871
#                                  2013  6.228735     1728980
#                                  2014  2.260274     1807532
# HOMICIDIOS                       2011  6.491553     1826952
#                                  2012  6.507496     1820658
#                                  2013  6.242370     1811473
#                                  2014  2.332552     1739371
# LESIONES                         2011  6.534870     1827828
#                                  2012  6.512541     1820658
# ...

# %%
# variant-3
df_sample.groupby(['category', 'year']).agg({'population':{'total_population':np.sum,
                                                               'mean_population':np.mean,
                                                               'variance_population':np.std},
                                                               'month':np.mean})
# Out:
# /Users/jacoboleon/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                             population                  \
#                                       total_population mean_population
# category                         year
# DELITOS PATRIMONIALES            2011        453808190    61036.743779
#                                  2012        480997130    46990.731731
#                                  2013        475415983    49296.555682
#                                  2014        151647239    53079.187609
# DELITOS SEXUALES (VIOLACION)     2011         68951497    61563.836607
#                                  2012         75809623    51888.859001
#                                  2013         64690174    46240.295926
# ...

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt
df[['month']['category'].plot(style='blue')
plt.title('Price Trends for Particular User')a

# %%
print(jell)
