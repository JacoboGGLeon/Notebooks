# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import requests

GOOGLE_MAPS_API_URL = 'http://maps.googleapis.com/maps/api/geocode/json'

# %%
data={}

data=[{'date': ['19 DE AGOSTO DE 2015'],
       'address': ['calle Yuriria, colonia Valle de Anáhuac, Ecatepec'],
       'link': ['https://afondoedomex.com/zona-oriente/secuestradores-tenian-a-tres-victimas-en-una-casa-de-seguridad-de-ecatepec/']},
       {'date': ['03 DE AGOSTO DE 2015'],
        'address': ['calle Benito Juarez esquina Riva Palacio, colonia Lomas de Chocolín, Chimalhuacan'],
        'link': ['https://afondoedomex.com/zona-oriente/rescatan-a-mujer-secuestrada-y-violada-en-casa-de-seguridad-de-chimalhuacan/']},
      {'date': ['1 DE JULIO DEL 2015'],
       'address': ['calle Guadalupe Victoria, colonia San Lucas Patoni, Tlalnepantla'],
       'link': ['https://afondoedomex.com/valle-de-mexico/secuestrado-escapa-por-una-ventana-de-casa-de-seguridad-en-tlalnepantla-detienen-a-5/']},
      {'date': ['06 DE MAYO DEL 2015'],
       'address': ['calle Sombrerete de la colonia Benito Juárez de Papantla, Veracruz'],
       'link': ['http://diarioelmartinense.com.mx/policiaca/64644-cae-banda-de-secuestradores-liberan-a-una-victima.html']},
      {'date': ['9 DE DICIEMBRE DE 2016'],
       'address': ['calle Girasoles esquina con Azucena, Las Américas, Ecatepec'],
       'link': ['https://afondoedomex.com/zona-oriente/jovencita-secuestrada-hace-una-semana-logra-escapar-de-casa-de-seguridad-en-ecatepec/']},
      {'date': ['3 DE OCTUBRE DEL 2014'],
       'address': ['calle Cali, colonia Las Américas, Ecatepec'],
       'link': ['https://afondoedomex.com/valle-de-mexico/joven-secuestrado-escapa-de-casa-de-seguridad-en-naucalpan-y-detienen-a-tres-plagiarios/']},
      {'date': ['12 de Febrero, 2018'],
       'address': ['calle chiapas, el encinar, Nogales, veracruz'],
       'link': ['https://www.alcalorpolitico.com/informacion/tras-operativo-liberan-a-mujer-secuestrada-en-nogales-257881.html']},
      {'date': ['FEBRERO 02, 2018'],
       'address': ['Calle Alvaro Obregón, Zona Centro, Saltillo, Coah.'],
       'link': ['http://www.excelsior.com.mx/nacional/2017/07/25/1177740']},
      {'date': ['09/03/2018'],
       'address': ['calle Félix Parra y Fernando Lea, fraccionamiento Paraíso, Coatzacoalcos, Veracruz'],
       'link': ['https://www.presencia.mx/nota.aspx?id=140349&s=7']},
      {'date': ['12/02/2018'],
       'address': ['calle juarez, Zona Centro, Saltillo, Coahuila'],
       'link': ['http://www.excelsior.com.mx/nacional/2017/07/25/1177740']}]

df_main = pd.DataFrame(data=data)
#df['id'] = df.index
df_main.reset_index(inplace=True)
#df.reset_index()
df_main
# Out:
#    index                                            address  \
# 0      0  [calle Yuriria, colonia Valle de Anáhuac, Ecat...
# 1      1  [calle Benito Juarez esquina Riva Palacio, col...
# 2      2  [calle Guadalupe Victoria, colonia San Lucas P...
# 3      3  [calle Sombrerete de la colonia Benito Juárez ...
# 4      4  [calle Girasoles esquina con Azucena, Las Amér...
# 5      5       [calle Cali, colonia Las Américas, Ecatepec]
# 6      6     [calle chiapas, el encinar, Nogales, veracruz]
# 7      7  [Calle Alvaro Obregón, Zona Centro, Saltillo, ...
# 8      8  [calle Félix Parra y Fernando Lea, fraccionami...
# 9      9    [calle juarez, Zona Centro, Saltillo, Coahuila]
#
#                        date                                               link
# 0    [19 DE AGOSTO DE 2015]  [https://afondoedomex.com/zona-oriente/secuest...
# 1    [03 DE AGOSTO DE 2015]  [https://afondoedomex.com/zona-oriente/rescata...
# 2     [1 DE JULIO DEL 2015]  [https://afondoedomex.com/valle-de-mexico/secu...
# 3     [06 DE MAYO DEL 2015]  [http://diarioelmartinense.com.mx/policiaca/64...
# 4  [9 DE DICIEMBRE DE 2016]  [https://afondoedomex.com/zona-oriente/jovenci...
# 5   [3 DE OCTUBRE DEL 2014]  [https://afondoedomex.com/valle-de-mexico/jove...
# 6     [12 de Febrero, 2018]  [https://www.alcalorpolitico.com/informacion/t...
# 7        [FEBRERO 02, 2018]  [http://www.excelsior.com.mx/nacional/2017/07/...
# 8              [09/03/2018]  [https://www.presencia.mx/nota.aspx?id=140349&...
# 9              [12/02/2018]  [http://www.excelsior.com.mx/nacional/2017/07/...

# %%
def check_value_in_list(list_for_check, value_for_check):
    result = False
    
    # traverse in the list
    for value_temporal in list_for_check:
        # compare with all the values
        # with val
#        print(value_temporal)
        if value_for_check == value_temporal:
#            print(value_temporal)
            result = True
    return result

# %%
def address_components_to_dict(resource, dictionary):
    for line in resource:
    #    print(line['types'])
    #    print(check_value_in_list(line['types'], 'locality'))

        #find street_number
        if(check_value_in_list(line['types'], 'street_number') == True):
#            print('street_number: ' + line['long_name'])
            dictionary['street_number'] = line['long_name']
#        elif(check_value_in_list(line['types'], 'street_number') == False):
#            dictionary['street_number'] = 'NaN'
            
        #find route
        elif(check_value_in_list(line['types'], 'route') == True):
#            print('route: ' + line['long_name'])
            dictionary['route'] = line['long_name']
#        elif(check_value_in_list(line['types'], 'route') == False):
#            dictionary['route'] = 'NaN'

        #find sublocality
        elif(check_value_in_list(line['types'], 'sublocality') == True):        
#            print('sublocality: ' + line['long_name'])
            dictionary['sublocality'] = line['long_name']
#        else:
#            dictionary['sublocality'] = 'NaN'

        #find locality
        elif(check_value_in_list(line['types'], 'locality') == True):        
#            print('locality: ' + line['long_name'])
            dictionary['locality'] = line['long_name']
#        else:
#            dictionary['locality'] = 'NaN'

        #find administrative_area
        elif(check_value_in_list(line['types'], 'administrative_area_level_1') == True):        
#            print('administrative_area: ' + line['long_name'])
            dictionary['administrative_area'] = line['long_name']
#        else:
#            dictionary['administrative_area'] = 'NaN'

        #find country
        elif(check_value_in_list(line['types'], 'country') == True):        
#            print('country: ' + line['long_name'])
            dictionary['country'] = line['long_name']
#        else:
#            dictionary['country'] = 'NaN'
            
    return dictionary

# %%
def address_to_location(address, key):
    #address = 'calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac'
    #address = 'calle Yuriria, Valle de Anahuac, Ecatepec de Morelos, México'
    #address = 'calle Guadalupe Victoria, colonia San Lucas Patoni, Tlalnepantla'
    #address = 'calle Girasoles, esquina con Azucena, Flores, Ecatepec'
    #address = 'Bondojito'
    #address = 'colonia Tepito'


    key = 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'

    import requests

    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'

    params = {
        'address': address, #'calle Yuriria, de la manzana 26, lote 12, en la colonia Valle de Anáhuac',
        'key': key #'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'
    }

    # Do the request and get the response data
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)
    res = req.json()

    # Use the first result
    #result = res['results'][0]

    #location_type
    location_type = res['results'][0]['geometry']['location_type']

    ##https://developers.google.com/maps/documentation/geocoding/intro

    geodata = dict()
#    geodata['place_id'] = res['results'][0]['place_id']
    geodata['lat'] = res['results'][0]['geometry']['location']['lat']
    geodata['lng'] = res['results'][0]['geometry']['location']['lng']
    geodata['location'] = [repr(geodata['lat']) + ',' + repr(geodata['lng'])]
    geodata['formatted_address'] = res['results'][0]['formatted_address']
    geodata['location_type'] = res['results'][0]['geometry']['location_type']

    address_components_to_dict(res['results'][0]['address_components'], geodata)

    """
    list(res['results'][0]) = ['address_components',
     'formatted_address',
     'geometry',
     'partial_match',
     'place_id',
     'types']
    """

    #list(res['results'][0])
    return geodata

# %%
address_to_location('calle Girasoles esquina con Azucena, Las Américas, Ecatepec', 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME')
# Out:
# {'administrative_area': 'Estado de México',
#  'country': 'Mexico',
#  'formatted_address': 'Azucena & Girasol, Jardines de Morelos, 55070 Ecatepec de Morelos, Méx., Mexico',
#  'lat': 19.6046103,
#  'lng': -99.0082321,
#  'locality': 'Ecatepec de Morelos',
#  'location': ['19.6046103,-99.0082321'],
#  'location_type': 'GEOMETRIC_CENTER',
#  'route': 'Azucena',
#  'sublocality': 'Jardines de Morelos'}

# %%
"""
df_casas = pd.DataFrame(columns=['formatted_address',
                                 'location', 'lat', 'lng',
                                 'location_type',
                                 'street_number', 'route', 'sublocality', 'locality', 'administrative_area', 'country'])
"""

df_casas = pd.DataFrame()
for line in df_main['address']:
    try:
#        print(line[0])
#        print(address_to_location(line[0], 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'))
        data = pd.DataFrame(address_to_location(line[0], 'AIzaSyAELcgNJs68gefdSp5TUxk73t8IUh3vTME'))
#        df_casas = pd.concat(df_sskjacasas, data)
#        print(data)
        
        df_casas = df_casas.append(data)
        
    except:
        pass
    

df_casas.reset_index()
# Out:
#    index   administrative_area country  \
# 0      0      Estado de México  Mexico
# 1      0      Estado de México  Mexico
# 2      0      Estado de México  Mexico
# 3      0              Veracruz  Mexico
# 4      0      Estado de México  Mexico
# 5      0      Estado de México  Mexico
# 6      0              Veracruz  Mexico
# 7      0  Coahuila de Zaragoza  Mexico
# 8      0              Veracruz  Mexico
# 9      0  Coahuila de Zaragoza  Mexico
#
#                                    formatted_address        lat         lng  \
# 0  Valle de Yuriria, Fuentes de Aragón, 55210 Eca...  19.516942  -99.027833
# 1  Vicente Riva Palacio & Benito Juárez, San Vice...  19.394686  -98.910416
# 2  Guadalupe Victoria, San Lucas Patoni, 54100 Tl...  19.533006  -99.160816
# 3  Sombrerete, Benito Juárez, Papantla de Olarte,...  20.454971  -97.329001
# 4  Azucena & Girasol, Jardines de Morelos, 55070 ...  19.604610  -99.008232
# 5  Cali, Fraccionamiento Las Americas, Sosa Texco...  19.585417  -99.013514
# 6  Calle Chiapas, Paseo Nuevo, 94720 Cd Mendoza, ...  18.809080  -97.192746
# 7  Calle Alvaro Obregón, Zona Centro, Saltillo, C...  25.421630 -101.009332
# 8  Fernando Lea & Felix Parra, Paraiso Coatzacoal...  18.147720  -94.475037
# 9  Juárez, Providencia, 25190 Saltillo, Coah., Me...  25.409532 -101.021363
#
#                 locality                       location     location_type  \
# 0    Ecatepec de Morelos          19.5169423,-99.027833  GEOMETRIC_CENTER
# 1  Chicoloapan de Juárez  19.3946857,-98.91041589999999  GEOMETRIC_CENTER
# 2           Tlalnepantla         19.5330056,-99.1608158  GEOMETRIC_CENTER
# 3     Papantla de Olarte          20.454971,-97.3290013  GEOMETRIC_CENTER
# 4    Ecatepec de Morelos         19.6046103,-99.0082321  GEOMETRIC_CENTER
# 5    Ecatepec de Morelos         19.5854168,-99.0135138  GEOMETRIC_CENTER
# 6         Ciudad Mendoza         18.8090801,-97.1927457  GEOMETRIC_CENTER
# 7               Saltillo        25.4216302,-101.0093317  GEOMETRIC_CENTER
# 8          Coatzacoalcos         18.1477198,-94.4750375  GEOMETRIC_CENTER
# 9               Saltillo        25.4095322,-101.0213633  GEOMETRIC_CENTER
#
#                   route            sublocality
# 0      Valle de Yuriria      Fuentes de Aragón
# 1  Vicente Riva Palacio            Chimalhucan
# 2    Guadalupe Victoria       San Lucas Patoni
# 3            Sombrerete          Benito Juárez
# 4               Azucena    Jardines de Morelos
# 5                  Cali           Sosa Texcoco
# 6         Calle Chiapas            Paseo Nuevo
# 7  Calle Alvaro Obregón            Zona Centro
# 8          Fernando Lea  Paraiso Coatzacoalcos
# 9                Juárez            Providencia
