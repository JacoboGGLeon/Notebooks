# %%
import pandas as pd
file = '../Datasets/envipe_2016_csv/0_indice_tablas_envipe2016.csv'
df = pd.read_csv(file)
df
# Out:
#   Encuesta Nacional de Victimización y Percepción sobre Seguridad Pública (ENVIPE) 2016  \
# 0                                                NaN
# 1                                  Nombre de archivo
# 2                                  thogar_envipe2016
# 3                                tmod_vic_envipe2016
# 4                               tper_vic1_envipe2016
# 5                               tper_vic2_envipe2016
# 6                                   tsdem_envipe2016
# 7                               tvivienda_envipe2016
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                   Título de tablas
# 2                                              Hogar
# 3                         Módulo sobre victimización
# 4  Percepción sobre seguridad y desempeño institu...
# 5  Percepción sobre seguridad, desempeño instituc...
# 6                               Residentes del hogar
# ...

# %%
file = '../Datasets/envipe_2016_csv/thogar_envipe2016/diccionario_de_datos/thogar.csv'
df = pd.read_csv(file, encoding='latin-1')
df
# Out:
#                                     NOMBRE_CAMPO    NEMÓNICO          TIPO  \
# 0         Identificador de vivienda seleccionada      ID_VIV  Alfanumérico
# 1           Identificador del hogar seleccionado      ID_HOG  Alfanumérico
# 2                      Control de vivienda (UPM)         UPM      Numérico
# 3                          Vivienda seleccionada     VIV_SEL      Numérico
# 4                              Control del hogar       HOGAR      Numérico
# 5                              Control del hogar       HOGAR      Numérico
# 6                Resultado de la visita al hogar     RESUL_H           NaN
# 7                Resultado de la visita al hogar     RESUL_H           NaN
# 8                Resultado de la visita al hogar     RESUL_H  Alfanumérico
# 9                Resultado de la visita al hogar     RESUL_H           NaN
# 10               Resultado de la visita al hogar     RESUL_H  Alfanumérico
# ...
