# %%
import pandas as pd
import numpy as np

# %%
#Residentes 117
path_residentes_117 = '../../Datasets/ENOE/dataframes/residentes_117.csv'

df_residentes_117 = pd.read_csv(path_residentes_117, low_memory=False, index_col=0)

df_residentes_117.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON   ...    \
# ID                                                                  ...
# 40015      0    1    2   10    103     0      1     1    9  40001   ...
# 40016      0    1    2   10    103     0      1     1    9  40001   ...
# 40017      0    1    2   10    103     0      1     1    9  40001   ...
# 40016      0    1    2   10    103     0      1     1    9  40001   ...
# 40017      0    1    2   10    103     0      1     1    9  40001   ...
#
#        P11_M5  P11_6  P11_H6  P11_M6  P11_7  P11_H7  P11_M7  P11_8  P11_H8  \
# ID
# 40015     NaN    NaN     NaN     NaN    7.0     1.0     0.0    NaN     NaN
# 40016     NaN    NaN     NaN     NaN    7.0    35.0     0.0    NaN     NaN
# 40017     NaN    NaN     NaN     NaN    7.0     4.0     0.0    NaN     NaN
# 40016     NaN    NaN     NaN     NaN    7.0     3.0     0.0    NaN     NaN
# 40017     NaN    NaN     NaN     NaN    7.0    36.0     0.0    NaN     NaN
#
# ...

# %%
#Residentes 217
path_residentes_217 = '../../Datasets/ENOE/dataframes/residentes_217.csv'

df_residentes_217 = pd.read_csv(path_residentes_217, low_memory=False, index_col=0)

df_residentes_217.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON  ...    \
# ID                                                                 ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
#
#        P9_M5  P9_6  P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8
# ID
# 40015    NaN   NaN    NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   7.0   18.0    0.0   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   7.0    1.0    0.0   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   7.0    7.0    0.0   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   7.0    7.0    0.0   NaN    NaN    NaN
#
# [5 rows x 311 columns]

# %%
#Residentes 317
path_residentes_317 = '../../Datasets/ENOE/dataframes/residentes_317.csv'

df_residentes_317 = pd.read_csv(path_residentes_317, low_memory=False, index_col=0)

df_residentes_317.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON  ...    \
# ID                                                                 ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
#
#        P9_M5  P9_6  P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8
# ID
# 40015    NaN   NaN    NaN    NaN   7.0   10.0    0.0   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   7.0   28.0    0.0   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   7.0   42.0    0.0   NaN    NaN    NaN
#
# [5 rows x 311 columns]

# %%
#Residentes 417
path_residentes_417 = '../../Datasets/ENOE/dataframes/residentes_417.csv'

df_residentes_417 = pd.read_csv(path_residentes_417, low_memory=False, index_col=0)

df_residentes_417.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON  ...    \
# ID                                                                 ...
# 40014      0    1    2   10    109     0      1     1    9  40001  ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
#
#        P9_M5  P9_6  P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8
# ID
# 40014    NaN   NaN    NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN
# 40015    NaN   NaN    NaN    NaN   7.0   20.0    0.0   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN
# 40015    NaN   NaN    NaN    NaN   7.0    2.0    0.0   NaN    NaN    NaN
#
# [5 rows x 311 columns]

# %% [markdown]
# ### Reconstrucción de variables de la ENOE: GRUPOS PRINCIPALES
#
# #### I. Población de 15 años y más
# + Población Económicamente Activa Ocupados + Desocupados
# + Población No Económicamente Activa Disponibles + No disponibles

# %% [markdown]
# #### II. Condición de actividad
# ##### Ocupados
# + Ocupado pleno P1=1
# + Ocupado sin pago P1a1=1 ó (P1a1=blanco y P1a2=2)
# + Ocupado ausente con nexo laboral (P1c= 01 ó 02 ó 03 ó 04) ó P1d=1
# + Ocupado ausente con retorno segurado (P1d=2 ó 9) y P1e=1
