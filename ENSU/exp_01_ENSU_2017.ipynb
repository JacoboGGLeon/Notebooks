# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carga
#
# ensu_cs = CVE_ENT + UPM + VIV_SEL + N_REN

# %%
ensu_viv_117 = '../../Datasets/ENSU/data/ensu_bd_marzo_2017_dbf/ENSU_VIV_0317.csv'

df_ensu_viv_117 = pd.read_csv(ensu_viv_117, low_memory=False, index_col=0)

df_ensu_viv_117.head()
# Out:
#       UPM  PRO_VIV  VIV_SEL  CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN  \
# 0  100105       31        1        1  Aguascalientes        1  Aguascalientes
# 1  100105       70        2        1  Aguascalientes        1  Aguascalientes
# 2  100105      104        3        1  Aguascalientes        1  Aguascalientes
# 3  100105      128        4        1  Aguascalientes        1  Aguascalientes
# 4  100105      167        5        1  Aguascalientes        1  Aguascalientes
#
#    LOC  CD  PER   ...     AP1_2  AP2_1  AP2_2 AP2_3  AP2_4  FAC_VIV  DOMINIO  \
# 0    1   1  117   ...         2      3      1   NaN    NaN    752.0        U
# 1    1   1  117   ...         2      2      1   NaN    NaN    752.0        U
# 2    1   1  117   ...         2      4      1   NaN    NaN    752.0        U
# 3    1   1  117   ...         1      1      1   NaN    NaN    752.0        U
# 4    1   1  117   ...         1      6      1   NaN    NaN    752.0        U
#
#    EST  UPM_DIS  EST_DIS
# ...

# %%
ensu_cs_117 = '../../Datasets/ENSU/data/ensu_bd_marzo_2017_dbf/ENSU_CS_0317.csv'

df_ensu_cs_117 = pd.read_csv(ensu_cs_117, low_memory=False, index_col=0)

df_ensu_cs_117.head()
# Out:
#       UPM  VIV_SEL  R_INF  CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN  \
# 0  100105        1      2        1  Aguascalientes        1  Aguascalientes
# 1  100105        1      2        1  Aguascalientes        1  Aguascalientes
# 2  100105        1      2        1  Aguascalientes        1  Aguascalientes
# 3  100105        2      2        1  Aguascalientes        1  Aguascalientes
# 4  100105        2      2        1  Aguascalientes        1  Aguascalientes
#
#    LOC  CD  PER   ...     A_ESC  C_ACT V_ACT  POS  FAC_VIV  FAC_SEL DOMINIO  \
# 0    1   1  117   ...       2.0    1.0   NaN  2.0    752.0      0.0       U
# 1    1   1  117   ...       2.0    1.0   NaN  3.0    752.0   1503.0       U
# 2    1   1  117   ...       2.0    NaN   NaN  NaN    752.0      0.0       U
# 3    1   1  117   ...       2.0    1.0   NaN  2.0    752.0      0.0       U
# 4    1   1  117   ...       2.0    5.0   4.0  NaN    752.0   1503.0       U
#
#    EST  UPM_DIS  EST_DIS
# 0    3       10      580
# ...

# %%
ensu_cb_117 = '../../Datasets/ENSU/data/ensu_bd_marzo_2017_dbf/ENSU_CB_0317.csv'

df_ensu_cb_117 = pd.read_csv(ensu_cb_117, low_memory=False, index_col=0)

df_ensu_cb_117.head()
# Out:
#       UPM  VIV_SEL  R_SEL  CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN  \
# 0  100105        1      2        1  Aguascalientes        1  Aguascalientes
# 1  100105        2      2        1  Aguascalientes        1  Aguascalientes
# 2  100105        3      2        1  Aguascalientes        1  Aguascalientes
# 3  100105        4      1        1  Aguascalientes        1  Aguascalientes
# 4  100105        5      1        1  Aguascalientes        1  Aguascalientes
#
#    LOC  CD  PER   ...     BP3_1_14  BP3_1_14E BP3_1_15 BP3_1_99  BP3_2  \
# 0    1   1  117   ...            0        NaN        0        0    2.0
# 1    1   1  117   ...            0        NaN        0        0    3.0
# 2    1   1  117   ...            0        NaN        0        0    2.0
# 3    1   1  117   ...            0        NaN        0        0    1.0
# 4    1   1  117   ...            0        NaN        0        0    4.0
#
#    FAC_SEL  DOMINIO  EST  UPM_DIS  EST_DIS
# ...

# %% [markdown]
# ### Construcción de IDs

# %%
id_ensu_viv_117 = (df_ensu_viv_117['CVE_ENT'] +
                   df_ensu_viv_117['UPM'] +
                   df_ensu_viv_117['VIV_SEL'])

id_ensu_viv_117.count()
# Out:
# 14497

# %%
id_ensu_cs_117 = (df_ensu_cs_117['CVE_ENT'] +
                  df_ensu_cs_117['UPM'] +
                  df_ensu_cs_117['VIV_SEL'] +
                  df_ensu_cs_117['N_REN'])

id_ensu_cs_117.count()
# Out:
# 49675

# %%
id_ensu_cb_117 = (df_ensu_cb_117['CVE_ENT'] +
                   df_ensu_cb_117['UPM'] +
                   df_ensu_cb_117['VIV_SEL'] +
                   df_ensu_cb_117['R_SEL'])

id_ensu_cb_117.count()
# Out:
# 14497

# %%
#copiamos para proteger la info
df_copy_ensu_viv_117 = df_ensu_viv_117.copy()
df_copy_ensu_cs_117 = df_ensu_cs_117.copy()
df_copy_ensu_cb_117 = df_ensu_cb_117.copy()

# %%
print(df_copy_ensu_viv_117.shape)
print(df_copy_ensu_cs_117.shape)
print(df_copy_ensu_cb_117.shape)
# Out:
# (14497, 26)
# (49675, 40)
# (14497, 136)

# %%
#se agrega la columna ID
df_copy_ensu_viv_117['ID'] = id_ensu_viv_117

#se coloca el ID previamente calculado
df_copy_ensu_viv_117.set_index(keys='ID', inplace=True)
df_copy_ensu_viv_117.head()
# Out:
#            UPM  PRO_VIV  VIV_SEL  CVE_ENT         NOM_ENT  CVE_MUN  \
# ID
# 100107  100105       31        1        1  Aguascalientes        1
# 100108  100105       70        2        1  Aguascalientes        1
# 100109  100105      104        3        1  Aguascalientes        1
# 100110  100105      128        4        1  Aguascalientes        1
# 100111  100105      167        5        1  Aguascalientes        1
#
#                NOM_MUN  LOC  CD  PER   ...     AP1_2  AP2_1  AP2_2 AP2_3  \
# ID                                     ...
# 100107  Aguascalientes    1   1  117   ...         2      3      1   NaN
# 100108  Aguascalientes    1   1  117   ...         2      2      1   NaN
# 100109  Aguascalientes    1   1  117   ...         2      4      1   NaN
# 100110  Aguascalientes    1   1  117   ...         1      1      1   NaN
# 100111  Aguascalientes    1   1  117   ...         1      6      1   NaN
#
#         AP2_4  FAC_VIV  DOMINIO  EST  UPM_DIS  EST_DIS
# ID
# ...

# %%
#se agrega la columna ID
df_copy_ensu_cs_117['ID'] = id_ensu_cs_117

#se coloca el ID previamente calculado
df_copy_ensu_cs_117.set_index(keys='ID', inplace=True)
df_copy_ensu_cs_117.head()
# Out:
#            UPM  VIV_SEL  R_INF  CVE_ENT         NOM_ENT  CVE_MUN  \
# ID
# 100108  100105        1      2        1  Aguascalientes        1
# 100109  100105        1      2        1  Aguascalientes        1
# 100110  100105        1      2        1  Aguascalientes        1
# 100109  100105        2      2        1  Aguascalientes        1
# 100110  100105        2      2        1  Aguascalientes        1
#
#                NOM_MUN  LOC  CD  PER   ...     A_ESC  C_ACT V_ACT  POS  \
# ID                                     ...
# 100108  Aguascalientes    1   1  117   ...       2.0    1.0   NaN  2.0
# 100109  Aguascalientes    1   1  117   ...       2.0    1.0   NaN  3.0
# 100110  Aguascalientes    1   1  117   ...       2.0    NaN   NaN  NaN
# 100109  Aguascalientes    1   1  117   ...       2.0    1.0   NaN  2.0
# 100110  Aguascalientes    1   1  117   ...       2.0    5.0   4.0  NaN
#
#         FAC_VIV  FAC_SEL DOMINIO  EST  UPM_DIS  EST_DIS
# ID
# ...

# %%
#se agrega la columna ID
df_copy_ensu_cb_117['ID'] = id_ensu_cb_117

#se coloca el ID previamente calculado
df_copy_ensu_cb_117.set_index(keys='ID', inplace=True)
df_copy_ensu_cb_117.head()
# Out:
#            UPM  VIV_SEL  R_SEL  CVE_ENT         NOM_ENT  CVE_MUN  \
# ID
# 100109  100105        1      2        1  Aguascalientes        1
# 100110  100105        2      2        1  Aguascalientes        1
# 100111  100105        3      2        1  Aguascalientes        1
# 100111  100105        4      1        1  Aguascalientes        1
# 100112  100105        5      1        1  Aguascalientes        1
#
#                NOM_MUN  LOC  CD  PER   ...     BP3_1_14  BP3_1_14E BP3_1_15  \
# ID                                     ...
# 100109  Aguascalientes    1   1  117   ...            0        NaN        0
# 100110  Aguascalientes    1   1  117   ...            0        NaN        0
# 100111  Aguascalientes    1   1  117   ...            0        NaN        0
# 100111  Aguascalientes    1   1  117   ...            0        NaN        0
# 100112  Aguascalientes    1   1  117   ...            0        NaN        0
#
#        BP3_1_99  BP3_2  FAC_SEL  DOMINIO  EST  UPM_DIS  EST_DIS
# ...

# %%
#exportar csv

path = '../../Datasets/ENSU/dataframes/seguridad_urbana_117.csv'

df_copy_ensu_cb_117.to_csv(path_or_buf=path, index=True, encoding='utf-8')
