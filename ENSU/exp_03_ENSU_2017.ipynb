# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carga

# %%
ensu_cb_116 = '../../Datasets/ENSU/data/ensu_bd_2016_dbf/ensu_bd_mar_2016_dbf/ENSU_CB0316.csv'

df_ensu_cb_116 = pd.read_csv(ensu_cb_116, low_memory=False, index_col=0)

df_ensu_cb_116.head()
# Out:
#    VIV_SEL  H_MUD  CD  ENT  MUN  LOC AGEB PRO_VIV  PER  R_DEF   ...     \
# 0        1      0   1    1    1    1    -       -  116      1   ...
# 1        2      0   1    1    1    1    -       -  116      1   ...
# 2        3      0   1    1    1    1    -       -  116      1   ...
# 3        4      0   1    1    1    1    -       -  116      1   ...
# 4        5      0   1    1    1    1    -       -  116      1   ...
#
#   BP3_1_15 BP3_1_16 BP3_1_16E BP3_2    FAC_SEL DOMINIO     UPM UPM_DIS  EST  \
# 0      NaN      NaN       NaN     2  1482.0696       U  100105      10    3
# 1      NaN      NaN       NaN     4  1482.0696       U  100105      10    3
# 2      NaN      NaN       NaN     3  1482.0696       U  100105      10    3
# 3      NaN      NaN       NaN     4  2223.1044       U  100105      10    3
# 4      NaN      NaN       NaN     4  1482.0696       U  100105      10    3
#
#    EST_DIS
# 0      490
# 1      490
# 2      490
# 3      490
# 4      490
#
# ...

# %%
ensu_cb_216 = '../../Datasets/ENSU/data/ensu_bd_2016_dbf/ensu_bd_jun_2016_dbf/ENSU_CB0616.csv'

df_ensu_cb_216 = pd.read_csv(ensu_cb_216, low_memory=False, index_col=0)

df_ensu_cb_216.head()
# Out:
#   Unnamed: 0.1     UPM VIV_SEL R_SEL ENT MUN LOC CD  PER R_DEF   ...    \
# 0            0  100105       1     2   1   1   1  1  216     1   ...
# 1            1  100105       2     2   1   1   1  1  216     1   ...
# 2            2  100105       3     2   1   1   1  1  216     1   ...
# 3            3  100105       4     1   1   1   1  1  216     1   ...
# 4            4  100105       5     1   1   1   1  1  216     1   ...
#
#   BP3_1_14 BP3_1_14E BP3_1_15 BP3_1_99 BP3_2 FAC_SEL DOMINIO EST UPM_DIS  \
# 0        0       NaN        0        0   3.0  1416.0       U   3      10
# 1        0       NaN        0        0   2.0  1416.0       U   3      10
# 2        0       NaN        0        0   2.0  1416.0       U   3      10
# 3        0       NaN        0        0   1.0   708.0       U   3      10
# 4        0       NaN        0        0   4.0  1416.0       U   3      10
#
#   EST_DIS
# 0    52.0
# 1    52.0
# 2    52.0
# 3    52.0
# 4    52.0
#
# [5 rows x 111 columns]

# %%
ensu_cb_316 = '../../Datasets/ENSU/data/ensu_bd_2016_dbf/ensu_bd_sep_2016_dbf/ENSU_CB_0916.csv'

df_ensu_cb_316 = pd.read_csv(ensu_cb_316, low_memory=False, index_col=0)

df_ensu_cb_316.head()
# Out:
#       UPM  VIV_SEL  R_SEL  ENT  MUN  LOC  CD  PER  R_DEF  H_MUD   ...     \
# 0  100105        1      2    1    1    1   1  316      1      0   ...
# 1  100105        2      2    1    1    1   1  316      1      0   ...
# 2  100105        3      2    1    1    1   1  316      1      0   ...
# 3  100105        4      1    1    1    1   1  316      1      0   ...
# 4  100105        5      1    1    1    1   1  316      1      0   ...
#
#   BP3_1_14 BP3_1_14E  BP3_1_15  BP3_1_99  BP3_2  FAC_SEL  DOMINIO  EST  \
# 0        0       NaN         0         0    2.0     1689        U    3
# 1        0       NaN         0         0    4.0     1689        U    3
# 2        0       NaN         0         0    2.0     1689        U    3
# 3        0       NaN         0         0    4.0      844        U    3
# 4        0       NaN         0         0    4.0     1689        U    3
#
#    UPM_DIS  EST_DIS
# 0       10      580
# 1       10      580
# 2       10      580
# 3       10      580
# ...

# %%
ensu_cb_416 = '../../Datasets/ENSU/data/ensu_bd_2016_dbf/ensu_bd_dic_2016_dbf/ENSU_CB_1216.csv'

df_ensu_cb_416 = pd.read_csv(ensu_cb_416, low_memory=False, index_col=0)

df_ensu_cb_416.head()
# Out:
#       UPM  VIV_SEL  R_SEL  CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN  \
# 0  100105        1      2        1  Aguascalientes        1  Aguascalientes
# 1  100105        2      2        1  Aguascalientes        1  Aguascalientes
# 2  100105        3      2        1  Aguascalientes        1  Aguascalientes
# 3  100105        4      1        1  Aguascalientes        1  Aguascalientes
# 4  100105        5      1        1  Aguascalientes        1  Aguascalientes
#
#    LOC  CD  PER   ...     BP3_1_14  BP3_1_14E BP3_1_15 BP3_1_99  BP3_2  \
# 0    1   1  416   ...            0        NaN        0        0    2.0
# 1    1   1  416   ...            0        NaN        0        0    3.0
# 2    1   1  416   ...            0        NaN        0        0    3.0
# 3    1   1  416   ...            0        NaN        0        0    4.0
# 4    1   1  416   ...            0        NaN        0        0    4.0
#
#    FAC_SEL  DOMINIO  EST  UPM_DIS  EST_DIS
# ...

# %%
frames_to_concat = [df_ensu_cb_116, df_ensu_cb_216, df_ensu_cb_316, df_ensu_cb_416]

# %%
df_ensu_cb = pd.concat(frames_to_concat, ignore_index=True)
df_ensu_cb.head()
# Out:
#   AGEB BP1_1 BP1_2_01 BP1_2_02 BP1_2_03 BP1_2_04 BP1_2_05 BP1_2_06 BP1_2_07  \
# 0    -     2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1    -     2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2    -     2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3    -     1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4    -     1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#   BP1_2_08   ...     PER  PRO_VIV R_DEF R_SEL SEL_SUST  TIPO_CUEST     UPM  \
# 0      NaN   ...     116        -     1     2      NaN           -  100105
# 1      NaN   ...     116        -     1     2      NaN           -  100105
# 2      NaN   ...     116        -     1     2      NaN           -  100105
# 3      NaN   ...     116        -     1     3      NaN           -  100105
# 4      NaN   ...     116        -     1     1      NaN           -  100105
#
#    UPM_DIS  Unnamed: 0.1  VIV_SEL
# ...

# %%
df_ensu_cb.shape
# Out:
# (60135, 146)

# %%
#exportar csv

path = '../../Datasets/ENSU/dataframes/percepcion_social_2016.csv'

df_ensu_cb.to_csv(path_or_buf=path, index=True, encoding='utf-8')
