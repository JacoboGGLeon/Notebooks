# %%
import pandas as pd
import numpy as np

# %%
ensu_cb = '../../Datasets/ENSU/dataframes/ensu_cb_02.csv'

df_ensu_cb = pd.read_csv(ensu_cb, low_memory=False, index_col=0)

df_ensu_cb.head()
# Out:
#    level_0  index AGEB  BP1_1 BP1_2_01 BP1_2_02 BP1_2_03 BP1_2_04 BP1_2_05  \
# 0        0      0    &      1        1        1        1        3        1
# 1        1      1    &      2        2        3        2        3        2
# 2        2      2    &      1        1        2        1        3        1
# 3        3      3    &      2        1        3        2        3        1
# 4        4      4    &      1        1        1        1        3        1
#
#   BP1_2_06   ...    PER PRO_VIV R_DEF R_SEL  SEL_SUST  TIPO_CUEST     UPM  \
# 0        1   ...    117       &     1     2         A           -  100105
# 1        2   ...    117       &     1     2         A           -  100105
# 2        1   ...    117       &     1     2         A           -  100105
# 3        1   ...    117       &     1     1         A           -  100105
# 4        1   ...    117       &     1     1         A           -  100105
#
#   UPM_DIS Unnamed: 0.1 VIV_SEL
# 0      10            &       1
# ...

# %%
df_ensu_cb.shape
# Out:
# (161810, 165)

# %%
df_copy_ensu_cb = df_ensu_cb.copy()
df_copy_ensu_cb.head()
# Out:
#    level_0  index AGEB  BP1_1 BP1_2_01 BP1_2_02 BP1_2_03 BP1_2_04 BP1_2_05  \
# 0        0      0    &      1        1        1        1        3        1
# 1        1      1    &      2        2        3        2        3        2
# 2        2      2    &      1        1        2        1        3        1
# 3        3      3    &      2        1        3        2        3        1
# 4        4      4    &      1        1        1        1        3        1
#
#   BP1_2_06   ...    PER PRO_VIV R_DEF R_SEL  SEL_SUST  TIPO_CUEST     UPM  \
# 0        1   ...    117       &     1     2         A           -  100105
# 1        2   ...    117       &     1     2         A           -  100105
# 2        1   ...    117       &     1     2         A           -  100105
# 3        1   ...    117       &     1     1         A           -  100105
# 4        1   ...    117       &     1     1         A           -  100105
#
#   UPM_DIS Unnamed: 0.1 VIV_SEL
# 0      10            &       1
# ...

# %%
df_copy_ensu_cb.LOC.value_counts()
# Out:
# 1       144132
# 37         986
# 54         759
# 67         595
# 77         576
# 16         561
# 2          536
# 17         483
# 3          453
# 21         431
# 9          410
# 5          408
# 13         407
# 122        367
# 43         358
# 10         349
# 49         348
# 47         337
# 33         305
# 6          299
# 32         297
# 45         285
# 19         278
# 15         272
# 18         270
# 4          266
# 20         260
# 40         259
# 41         258
# 137        257
#          ...
# 140         53
# 60          52
# 106         51
# 26          50
# 181         50
# 150         50
# 30          50
# 1025        50
# 78          50
# 991         48
# 232         46
# 29          44
# 212         43
# 217         43
# 28          42
# 1599        41
# 111         39
# 230         37
# 231         36
# 72          36
# 192         30
# 95          29
# 157         26
# 24          25
# 206         25
# 187         25
# 160         24
# ...

# %%
df_copy_ensu_cb.groupby(['CVE_ENT', 'CVE_MUN', 'LOC']).aggregate(np.median)
# Out:
#                        level_0     index  BP1_1  BP1_2_10  BP1_2_11  BP1_2_12  \
# CVE_ENT CVE_MUN LOC
# 1       1       1      75625.0   75628.0    2.0       1.0       2.0       1.0
#                 21    146410.5  147356.5    1.0       2.0       2.0       3.0
#                 49    149730.5  152867.5    1.0       1.0       1.0       2.5
#         5       1      68219.0   68221.5    2.0       1.0       2.0       2.0
#                 23     60692.0   60694.0    2.0       1.0       2.0       2.0
# 2       1       2     142611.0  142617.0    1.0       1.0       2.0       3.0
#                 5     143385.0  143391.0    1.0       1.0       1.0       3.0
#                 9     143840.5  143998.5    1.0       2.0       2.0       3.0
#                 18    144628.5  145574.5    1.0       2.0       2.0       3.0
#         2       1      75871.0   75874.0    2.0       1.0       2.0       2.0
#                 262   131209.0  131214.0    2.0       2.0       2.0       2.0
# ...
