# %%
# %matplotlib inline 
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carga
# Por cada vivienda existe uno o más hogares y por cada hogar con entrevista lograda se tiene uno o más
# residentes (características sociodemográficas), es decir, para cada hogar se tiene el registro de sus residentes en la tabla de sociodemográfico (SDEM) y a su vez, para cada residente con edad de 12 años cumplidos ó más, se tiene un registro del Cuestionario de Ocupación y Empleo, el cual se almacena en las tablas COE1 (de batería 1 a 5) y COE2 (de batería 6 a la 11 para el COE ampliado o a la batería 9 para el COE básico).
#
# Se cargan las tablas en dataframes:
# + vivt: Datos de las viviendas
#     + ID_vivt: CD_A + ENT + CON + V_SEL
# + hogt: Datos de los hogares
# + sdemt: Características sociodemográficas de los residentes
# + coe1t y coe2t: Datos de ocupación y empleo de las personas de 12 años y más

# %%
#Conjunto de datos de la Tabla Vivienda del trimestre 3 del 2017
vivt_enoe417 = '../../Datasets/ENOE/2017_trim4_enoe_csv/vivt_enoe417/conjunto_de_datos/vivt417.csv'

df_vivt_enoe417 = pd.read_csv(vivt_enoe417, low_memory=False, index_col=0, encoding='latin1')

df_vivt_enoe417.reset_index(inplace=True)

df_vivt_enoe417.head()
# Out:
#    LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON     UPM  D_SEM  \
# 0    1    1   30      2     0      1    14    1  40001  101725    101
# 1    1    1   30      2     0      1    14    1  40001  101725    101
# 2    1    1   30      2     0      1    14    1  40001  101725    101
# 3    1    1   30      2     0      1    14    1  40001  101725    101
# 4    1    1   30      2     0      1    14    1  40001  101725    101
#
#    N_PRO_VIV  V_SEL  N_ENT  PER   P1   P2  P3  UR  FAC
# 0         97      1      1  417  6.0  1.0 NaN   1  113
# 1        125      2      1  417  3.0  1.0 NaN   1  113
# 2         61      3      1  417  3.0  1.0 NaN   1  113
# 3         85      4      1  417  3.0  1.0 NaN   1  113
# 4         26      5      1  417  5.0  1.0 NaN   1  113

# %%
#Conjunto de datos de la Tabla Hogar del trimestre 3 del 2017
hogt_enoe417 = '../../Datasets/ENOE/2017_trim4_enoe_csv/hogt_enoe417/conjunto_de_datos/hogt417.csv'

df_hogt_enoe417 = pd.read_csv(hogt_enoe417, low_memory=False, index_col=0, encoding='latin1')

df_hogt_enoe417.reset_index(inplace=True)

df_hogt_enoe417.head()
# Out:
#    LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON     UPM ...   R_DEF  \
# 0    1    1   30      2     0      1    14    1  40001  101725 ...       0
# 1    1    1   30      2     0      1    14    1  40001  101725 ...       0
# 2    1    1   30      2     0      1    14    1  40001  101725 ...       0
# 3    1    1   30      2     0      1    14    1  40001  101725 ...       0
# 4    1    1   30      2     0      1    14    1  40001  101725 ...       0
#
#    D_DIA  D_MES  D_ANIO  E_OBS  P4_1  P4_2  INF  UR  FAC
# 0      6     10      17    2.0   4.0   NaN    2   1  113
# 1      8     10      17    2.0   4.0   NaN    2   1  113
# 2      5     10      17    2.0   4.0   NaN    3   1  113
# 3     10     10      17    2.0   4.0   NaN    2   1  113
# 4      5     10      17    2.0   4.0   NaN    2   1  113
#
# [5 rows x 31 columns]

# %%
#Conjunto de datos de la Tabla Sociodemográfica del trimestre 3 del 2017
sdemt_enoe417 = '../../Datasets/ENOE/2017_trim4_enoe_csv/sdemt_enoe417/conjunto_de_datos/sdemt417.csv'

df_sdemt_enoe417 = pd.read_csv(sdemt_enoe417, low_memory=False, index_col=0, encoding='latin1')

df_sdemt_enoe417.reset_index(inplace=True)

df_sdemt_enoe417.head()
# Out:
#    R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON   ...     \
# 0      0    1    2   10    109     0      1     1    9  40001   ...
# 1      0    1    2   10    109     0      1     1    9  40001   ...
# 2      0    1    2   10    109     0      1     1    9  40001   ...
# 3      0    1    2   10    109     0      1     1    9  40001   ...
# 4      0    1    2   10    109     0      1     1    9  40001   ...
#
#    MA48ME1SM  P14APOYOS  SCIAN  T_TRA  EMP_PPAL  TUE_PPAL  TRANS_PPAL  \
# 0          0          0      5      1         2         2           0
# 1          0          0      0      1         0         0           0
# 2          0          0      0      1         0         0           0
# 3          0          0      0      1         0         0           0
# 4          0          0     12      1         2         2           0
#
#    MH_FIL2  MH_COL  SEC_INS
# 0        3       2        2
# 1        0       0        0
# 2        0       0        0
# ...

# %%
#Conjunto de datos de la Tabla Ocupación y Empleo 1 del trimestre 3 del 2017
coe1t_enoe417 = '../../Datasets/ENOE/2017_trim4_enoe_csv/coe1t_enoe417/conjunto_de_datos/coe1t417.csv'

df_coe1t_enoe417 = pd.read_csv(coe1t_enoe417, low_memory=False, index_col=0, encoding='latin1')

df_coe1t_enoe417.reset_index(inplace=True)

df_coe1t_enoe417.head()
# Out:
#    R_DEF  CD_A  ENT    CON     UPM  D_SEM  N_PRO_VIV  V_SEL  N_HOG  H_MUD  \
# 0      0     1    9  40001  900471    101          9      1      1      0
# 1      0     1    9  40001  900471    101          9      1      1      0
# 2      0     1    9  40001  900471    101          9      1      1      0
# 3      0     1    9  40001  900471    101          9      1      1      0
# 4      0     1    9  40001  900471    101         34      2      1      0
#
#   ...   P5F9  P5F10  P5F11  P5F12  P5F13  P5F14  P5F15  P5F99  UR  FAC
# 0 ...    NaN    NaN    NaN    NaN    NaN   14.0    NaN    NaN   1  517
# 1 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 2 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 3 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 4 ...    NaN    NaN    NaN    NaN    NaN   14.0    NaN    NaN   1  517
#
# [5 rows x 169 columns]

# %%
#Conjunto de datos de la Tabla Ocupación y Empleo 2 del trimestre 3 del 2017
coe2t_enoe417 = '../../Datasets/ENOE/2017_trim4_enoe_csv/coe2t_enoe417/conjunto_de_datos/coe2t417.csv'

df_coe2t_enoe417 = pd.read_csv(coe2t_enoe417, low_memory=False, index_col=0, encoding='latin1')

df_coe2t_enoe417.reset_index(inplace=True)

df_coe2t_enoe417.head()
# Out:
#    CD_A  ENT    CON     UPM  D_SEM  N_PRO_VIV  V_SEL  N_HOG  H_MUD  N_ENT  \
# 0     1    9  40001  900471    101          9      1      1      0      1
# 1     1    9  40001  900471    101          9      1      1      0      1
# 2     1    9  40001  900471    101          9      1      1      0      1
# 3     1    9  40001  900471    101          9      1      1      0      1
# 4     1    9  40001  900471    101         34      2      1      0      1
#
#   ...   P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8  UR  FAC
# 0 ...     NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN   1  517
# 1 ...     NaN    NaN   7.0   20.0    0.0   NaN    NaN    NaN   1  517
# 2 ...     NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN   1  517
# 3 ...     NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN   1  517
# 4 ...     NaN    NaN   7.0    2.0    0.0   NaN    NaN    NaN   1  517
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Análisis

# %%
print(df_hogt_enoe417.R_DEF.astype('category').cat.codes.unique())
print(df_sdemt_enoe417.R_DEF.astype('category').cat.codes.unique())
print(df_coe1t_enoe417.R_DEF.astype('category').cat.codes.unique())
# Out:
# [ 0  6  7  3  2  1  9  5  4  8 11 12 10 13 14]
# [0 1]
# [0]

# %%
print(df_vivt_enoe417.shape)
print(df_hogt_enoe417.shape)
print(df_sdemt_enoe417.shape)
print(df_coe1t_enoe417.shape)
print(df_coe2t_enoe417.shape)
# Out:
# (122681, 20)
# (123354, 31)
# (391620, 104)
# (307759, 169)
# (307759, 70)

# %% [markdown]
# ### Construcción de IDs

# %%
id_df_vivt_enoe417 = (df_vivt_enoe417['CD_A'] +
                      df_vivt_enoe417['ENT'] +
                      df_vivt_enoe417['CON'] +
                      df_vivt_enoe417['V_SEL'])

id_df_vivt_enoe417.count()
# Out:
# 122681

# %%
id_df_hogt_enoe417 = (df_hogt_enoe417['CD_A'] +
                      df_hogt_enoe417['ENT'] +
                      df_hogt_enoe417['CON'] +
                      df_hogt_enoe417['V_SEL'] +
                      df_hogt_enoe417['N_HOG'] +
                      df_hogt_enoe417['H_MUD'])  

id_df_hogt_enoe417.count()
# Out:
# 123354

# %%
id_df_sdemt_enoe417 = (df_sdemt_enoe417['CD_A'] +
                      df_sdemt_enoe417['ENT'] +
                      df_sdemt_enoe417['CON'] +
                      df_sdemt_enoe417['V_SEL'] +
                      df_sdemt_enoe417['N_HOG'] +
                      df_sdemt_enoe417['H_MUD'] + 
                      df_sdemt_enoe417['N_REN'])   

id_df_sdemt_enoe417.count()
# Out:
# 391620

# %%
id_df_coe1t_enoe417 = (df_coe1t_enoe417['CD_A'] +
                      df_coe1t_enoe417['ENT'] +
                      df_coe1t_enoe417['CON'] +
                      df_coe1t_enoe417['V_SEL'] +
                      df_coe1t_enoe417['N_HOG'] +
                      df_coe1t_enoe417['H_MUD'] + 
                      df_coe1t_enoe417['N_REN'])   

id_df_coe1t_enoe417.count()
# Out:
# 307759

# %%
id_df_coe2t_enoe417 = (df_coe2t_enoe417['CD_A'] +
                      df_coe2t_enoe417['ENT'] +
                      df_coe2t_enoe417['CON'] +
                      df_coe2t_enoe417['V_SEL'] +
                      df_coe2t_enoe417['N_HOG'] +
                      df_coe2t_enoe417['H_MUD'] + 
                      df_coe2t_enoe417['N_REN'])   

id_df_coe2t_enoe417.count()
# Out:
# 307759

# %% [markdown]
# ### Reconstrucción de variables

# %%
#copiamos para proteger la info
df_copy_sdemt_enoe417 = df_sdemt_enoe417.copy()
df_copy_coe1t_enoe417 = df_coe1t_enoe417.copy()
df_copy_coe2t_enoe417 = df_coe2t_enoe417.copy()

# %%
#se agrega la columna ID
df_copy_sdemt_enoe417['ID'] = id_df_sdemt_enoe417

#se coloca el ID previamente calculado
df_copy_sdemt_enoe417.set_index(keys='ID', inplace=True)
df_copy_sdemt_enoe417.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON   ...     \
# ID                                                                  ...
# 40014      0    1    2   10    109     0      1     1    9  40001   ...
# 40015      0    1    2   10    109     0      1     1    9  40001   ...
# 40016      0    1    2   10    109     0      1     1    9  40001   ...
# 40017      0    1    2   10    109     0      1     1    9  40001   ...
# 40015      0    1    2   10    109     0      1     1    9  40001   ...
#
#        MA48ME1SM  P14APOYOS  SCIAN  T_TRA  EMP_PPAL  TUE_PPAL  TRANS_PPAL  \
# ID
# 40014          0          0      5      1         2         2           0
# 40015          0          0      0      1         0         0           0
# 40016          0          0      0      1         0         0           0
# 40017          0          0      0      1         0         0           0
# 40015          0          0     12      1         2         2           0
#
# ...

# %%
#se agrega la columna ID
df_copy_coe1t_enoe417['ID'] = id_df_coe1t_enoe417

#se coloca el ID previamente calculado
df_copy_coe1t_enoe417.set_index(keys='ID', inplace=True)
df_copy_coe1t_enoe417.head()
# Out:
#        R_DEF  CD_A  ENT    CON     UPM  D_SEM  N_PRO_VIV  V_SEL  N_HOG  H_MUD  \
# ID
# 40014      0     1    9  40001  900471    101          9      1      1      0
# 40015      0     1    9  40001  900471    101          9      1      1      0
# 40016      0     1    9  40001  900471    101          9      1      1      0
# 40017      0     1    9  40001  900471    101          9      1      1      0
# 40015      0     1    9  40001  900471    101         34      2      1      0
#
#       ...   P5F9  P5F10  P5F11  P5F12  P5F13  P5F14  P5F15  P5F99  UR  FAC
# ID    ...
# 40014 ...    NaN    NaN    NaN    NaN    NaN   14.0    NaN    NaN   1  517
# 40015 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 40016 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 40017 ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   1  517
# 40015 ...    NaN    NaN    NaN    NaN    NaN   14.0    NaN    NaN   1  517
#
# [5 rows x 169 columns]

# %%
#se agrega la columna ID
df_copy_coe2t_enoe417['ID'] = id_df_coe2t_enoe417

#se coloca el ID previamente calculado
df_copy_coe2t_enoe417.set_index(keys='ID', inplace=True)
df_copy_coe2t_enoe417.head()
# Out:
#        CD_A  ENT    CON     UPM  D_SEM  N_PRO_VIV  V_SEL  N_HOG  H_MUD  N_ENT  \
# ID
# 40014     1    9  40001  900471    101          9      1      1      0      1
# 40015     1    9  40001  900471    101          9      1      1      0      1
# 40016     1    9  40001  900471    101          9      1      1      0      1
# 40017     1    9  40001  900471    101          9      1      1      0      1
# 40015     1    9  40001  900471    101         34      2      1      0      1
#
#       ...   P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8  UR  FAC
# ID    ...
# 40014 ...     NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN   1  517
# 40015 ...     NaN    NaN   7.0   20.0    0.0   NaN    NaN    NaN   1  517
# 40016 ...     NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN   1  517
# 40017 ...     NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN   1  517
# 40015 ...     NaN    NaN   7.0    2.0    0.0   NaN    NaN    NaN   1  517
#
# [5 rows x 70 columns]

# %%
df_residentes = pd.DataFrame()
"""
df_residentes = df_copy_sdemt_enoe417.merge(right=(df_copy_coe1t_enoe417.merge(right=df_copy_coe2t_enoe417, 
                                                                               how='inner')), 
                                            how='inner')
"""

df_residentes = df_copy_sdemt_enoe417.reset_index().merge(right=(df_copy_coe1t_enoe417.merge(right=df_copy_coe2t_enoe417, 
                                                                               how='inner')), 
                                            how='inner').set_index('ID')

df_residentes.head()
# Out:
#        R_DEF  LOC  MUN  EST  EST_D  AGEB  T_LOC  CD_A  ENT    CON  ...    \
# ID                                                                 ...
# 40014      0    1    2   10    109     0      1     1    9  40001  ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
# 40016      0    1    2   10    109     0      1     1    9  40001  ...
# 40017      0    1    2   10    109     0      1     1    9  40001  ...
# 40015      0    1    2   10    109     0      1     1    9  40001  ...
#
#        P9_M5  P9_6  P9_H6  P9_M6  P9_7  P9_H7  P9_M7  P9_8  P9_H8  P9_M8
# ID
# 40014    NaN   NaN    NaN    NaN   NaN    NaN    NaN   NaN    NaN    NaN
# 40015    NaN   NaN    NaN    NaN   7.0   20.0    0.0   NaN    NaN    NaN
# 40016    NaN   NaN    NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN
# 40017    NaN   NaN    NaN    NaN   7.0    3.0    0.0   NaN    NaN    NaN
# 40015    NaN   NaN    NaN    NaN   7.0    2.0    0.0   NaN    NaN    NaN
#
# [5 rows x 311 columns]

# %%
#Se convierte a categorico
for column in df_residentes.columns:
    df_residentes[column] = df_residentes[column].astype('category')

# %%
#df_residentes.R_DEF = df_residentes.R_DEF.astype('category')

#se seleccionan las entrevistas completas y con condición de residencia
df_residentes = df_residentes[(df_residentes['R_DEF'] == 0) & ((df_residentes['C_RES'] == 1) | (df_residentes['C_RES'] == 3))]
df_residentes.head()
# Out:
#       R_DEF LOC MUN EST EST_D AGEB T_LOC CD_A ENT    CON  ...  P9_M5 P9_6  \
# ID                                                        ...
# 40014     0   1   2  10   109    0     1    1   9  40001  ...    NaN  NaN
# 40015     0   1   2  10   109    0     1    1   9  40001  ...    NaN  NaN
# 40016     0   1   2  10   109    0     1    1   9  40001  ...    NaN  NaN
# 40017     0   1   2  10   109    0     1    1   9  40001  ...    NaN  NaN
# 40015     0   1   2  10   109    0     1    1   9  40001  ...    NaN  NaN
#
#       P9_H6 P9_M6 P9_7 P9_H7 P9_M7 P9_8 P9_H8 P9_M8
# ID
# 40014   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 40015   NaN   NaN  7.0  20.0   0.0  NaN   NaN   NaN
# 40016   NaN   NaN  7.0   3.0   0.0  NaN   NaN   NaN
# 40017   NaN   NaN  7.0   3.0   0.0  NaN   NaN   NaN
# 40015   NaN   NaN  7.0   2.0   0.0  NaN   NaN   NaN
#
# [5 rows x 311 columns]

# %%
df_residentes.shape
# Out:
# (307759, 311)

# %%
#exportar csv

path = '../../Datasets/ENOE/dataframes/residentes_417.csv'

df_residentes.to_csv(path_or_buf=path, index=True, encoding='utf-8')
