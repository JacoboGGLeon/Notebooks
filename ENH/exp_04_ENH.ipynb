# %%
import pandas as pd
import numpy as np

# %%
vivienda = '../../Datasets/ENH/dataframes/vivienda2.csv'

df_vivienda = pd.read_csv(vivienda, low_memory=False)

df_vivienda.head()
# Out:
#    Unnamed: 0  level_0  CVE_ENT  CVE_LOC  CVE_MUN   ageb  aire_acond ais_otro  \
# 0           0        0        1        1        1  029-0           2        &
# 1           1        1        1        1        1  029-0           2        &
# 2           2        2        1        1        1  029-0           2        &
# 3           3        3        1        1        1  029-0           2        &
# 4           4        4        1        1        1  030-3           2        &
#
#   ais_pared ais_techos    ...     tipo_viv tot_hog tot_resid tv_paga  \
# 0         &          &    ...            1       1         4       &
# 1         &          &    ...            1       1         4       &
# 2         &          &    ...            1       1         2       &
# 3         &          &    ...            1       1         6       &
# 4         &          &    ...            1       1         4       &
#
#   ubica_geo   upm uso_compar  valor_viv  vend_hered  viv_usada
# ...

# %%
df_vivienda.shape
# Out:
# (160467, 118)

# %%
#categorizar y quitar columnas
#df_vivienda_filtered = df_vivienda_filtered[['']]

# %%
df_vivienda.groupby(['CVE_ENT', 'CVE_MUN', 'CVE_LOC']).aggregate(np.median)
# Out:
#                          Unnamed: 0   level_0  aire_acond  bomba_agua  \
# CVE_ENT CVE_MUN CVE_LOC
# 1       1       1           44558.5   44558.5         2.0         2.0
#                 138        103998.5  103998.5         2.0         2.0
#                 144          1184.5    1184.5         2.0         2.0
#                 239         45170.0   45170.0         2.0         2.0
#                 293        103772.0  103772.0         2.0         2.0
#                 345         45379.0   45379.0         2.0         2.0
#                 367          1089.0    1089.0         2.0         2.0
#                 426        104063.5  104063.5         2.0         1.0
#                 429        103970.0  103970.0         2.0         2.0
#                 548        104018.0  104018.0         2.0         1.0
#                 558         45479.5   45479.5         2.0         2.0
#                 605        104030.0  104030.0         2.0         2.0
# ...
